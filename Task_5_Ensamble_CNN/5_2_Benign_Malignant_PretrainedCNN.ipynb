# %% [markdown]
# # TASK 5

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Utility function

# %%
# %tensorflow_version 2.x
import os
import itertools
import csv
import numpy as np
import tensorflow as tf
from sklearn.utils import class_weight
import random as rn
from numpy import dstack
from sklearn.utils import class_weight
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import fbeta_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC, SVC
from keras.applications.inception_v3 import preprocess_input 
from keras.applications.resnet50 import preprocess_input as resnet_process_input
import matplotlib.pyplot as plt
from skimage import exposure
from tensorflow.compat.v1.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Parameters
DIR_PATH = '/content/drive/Shareddrives/Verna_Minutella_Veltroni'
MODEL_PATH = os.path.join(DIR_PATH, 'models/models_task5_2') 
NUMPY_PATH = os.path.join(DIR_PATH, 'numpy_data')

BATCH_SIZE = 64


# Set seed for reproducibility
tf.keras.backend.clear_session()

seed_num = 1
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed_num)
rn.seed(seed_num)
tf.random.set_seed(seed_num)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ### Loading training and test set

# %%
# Loading test set
def load_train():
  images = np.load(os.path.join(NUMPY_PATH,'train_tensor.npy'))
  labels = np.load(os.path.join(NUMPY_PATH,'train_labels.npy'))
  return images, labels

def load_test():
  images = np.load(os.path.join(NUMPY_PATH,'public_test_tensor.npy'))
  labels = np.load(os.path.join(NUMPY_PATH,'public_test_labels.npy'))
  return images, labels

# %% [markdown]
# ### Plotting the confusion matrix

# %%
# function to print the confusion matrix
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    specificity = cm[0,0]/(cm[0,0]+cm[0,1])
    print('Specificity : ', specificity )

    sensitivity = cm[1,1]/(cm[1,0]+cm[1,1])
    print('Sensitivity : ', sensitivity)
    plt.show()

# %% [markdown]
# ### Plotting the ROC curve

# %%
def plot_roc_curve(probs, test_labels):
    f = fbeta_score(test_labels, np.rint(probs), beta=2.0)
    print('Result: f2_score=%.3f' % (f))

    fpr, tpr, threshold = roc_curve(test_labels, probs)
    roc_auc = auc(fpr, tpr) 
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# ### Plotting accuracy and loss trends

# %%
def performance_plot(history, model):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'r', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  fig1 = plt.figure()

  plt.plot(epochs, loss, 'r', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# ### Setting the seed

# %%
# function to set the seed before each execution of the model
def set_seed():
    tf.keras.backend.clear_session()

    seed_num = 1
    os.environ['PYTHONHASHSEED'] = '0'
    np.random.seed(seed_num)
    rn.seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    K.set_session(sess)

# %% [markdown]
# ## Dataset creation

# %%
train_img, train_lab = load_train()
test_img, test_lab = load_test()

# %%
# TRAINING SET
abnormality_images = train_img[1::2] 
abnormality_labels = train_lab[1::2]

abnormality_images = abnormality_images.reshape((2676, 150, 150, 1)) 
abnormality_images = abnormality_images.astype('float32') * 0.003891051

# mass
abnormality_labels[abnormality_labels == 1] = 0
abnormality_labels[abnormality_labels == 3] = 0
# calcification
abnormality_labels[abnormality_labels == 2] = 1
abnormality_labels[abnormality_labels == 4] = 1

# VALIDATION SET
train_images, valid_images, train_labels, valid_labels = train_test_split(abnormality_images, abnormality_labels, test_size=0.30, random_state=42, stratify=abnormality_labels)

# TEST SET
test_images = test_img[1::2]
test_labels = test_lab[1::2]

test_images = test_images.reshape((336, 150, 150, 1))
test_images = test_images.astype('float32') * 0.003891051


# mass
test_labels[test_labels == 1] = 0
test_labels[test_labels == 3] = 0
# calcification
test_labels[test_labels == 2] = 1
test_labels[test_labels == 4] = 1

# %% [markdown]
# ## Loading the best models

# %%
model1 = models.load_model(os.path.join(DIR_PATH, 'models/models_task2_2/model7_best.h5'))
#result = model1.evaluate(test_images, test_labels, batch_size=64)
#print(result)

model3 = models.load_model(os.path.join(DIR_PATH, 'models/models_task3_2/inception4_best.h5'))
#result = model3.evaluate(test, test_labels, batch_size=64)
#print(result)

model4 = models.load_model(os.path.join(DIR_PATH, 'models/models_task3_2/resnet3_best.h5'))
#result = model4.evaluate(test1, test_labels, batch_size=64)
#print(result)

# %% [markdown]
# ### Inception and scratch model preprocessing

# %%
def scratch_preprocessing(input):
  return input/255

def inception_preprocess(input):
  return preprocess_input(np.repeat(input, 3, axis=3))

def resnet_preprocess(input):
  return resnet_process_input(np.repeat(input, 3, axis=3))

# %% [markdown]
# ## Ensemble with loaded models

# %% [markdown]
# ### Logistic Regression

# %%
set_seed()

# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = pred
		else:
			stackX = dstack((stackX, pred))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # fit standalone model
    model = LogisticRegression(max_iter=500, random_state=13, class_weight='balanced')
    model.fit(stackedX, inputy)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': model1, 'preprocess': scratch_preprocessing}, 
         {'model': model4, 'preprocess': resnet_preprocess},
         {'model': model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble, os.path.join(MODEL_PATH, 'logreg_pretrained.h5'))

train_pred = stacked_prediction(members, ensemble, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble on test set
pred = stacked_prediction(members, ensemble, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Stacked Train Accuracy: 0.792
# Stacked Test Accuracy: 0.693
# Specificity :  0.6484018264840182
# Sensitivity :  0.7777777777777778
# Result: f2_score=0.715
# Stacked Valid Accuracy: 0.770
# Specificity :  0.7940552016985138
# Sensitivity :  0.7349397590361446

# %% [markdown]
# ### Linear SVC

# %%
set_seed()

# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = pred
		else:
			stackX = dstack((stackX, pred))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# fit standalone model
	model = CalibratedClassifierCV(base_estimator=LinearSVC(random_state=13, class_weight='balanced'))
	model.fit(stackedX, inputy)
	return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': model1, 'preprocess': scratch_preprocessing}, 
         {'model': model4, 'preprocess': resnet_preprocess},
         {'model': model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble2 = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble2, os.path.join(MODEL_PATH, 'lsvc_pretrained.h5'))


train_pred = stacked_prediction(members, ensemble2, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble2 on test set
pred = stacked_prediction(members, ensemble2, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble2, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Stacked Train Accuracy: 0.790
# Stacked Test Accuracy: 0.717
# Specificity :  0.7214611872146118
# Sensitivity :  0.7094017094017094
# Result: f2_score=0.678
# Stacked Valid Accuracy: 0.770
# Specificity :  0.8407643312101911
# Sensitivity :  0.6686746987951807

# %% [markdown]
# ### SVC

# %%
set_seed()

# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = pred
		else:
			stackX = dstack((stackX, pred))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# fit standalone model
	model = SVC(probability=True, random_state=13, class_weight='balanced')
	model.fit(stackedX, inputy)
	return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': model1, 'preprocess': scratch_preprocessing}, 
         {'model': model4, 'preprocess': resnet_preprocess},
         {'model': model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble3 = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble3, os.path.join(MODEL_PATH, 'svc_pretrained.h5'))

train_pred = stacked_prediction(members, ensemble3, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)
# evaluate ensemble3 on test set
pred = stacked_prediction(members, ensemble3, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble3, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Stacked Train Accuracy: 0.792
# Stacked Test Accuracy: 0.690
# Specificity :  0.6757990867579908
# Sensitivity :  0.717948717948718
# Result: f2_score=0.674
# Stacked Valid Accuracy: 0.766
# Specificity :  0.8131634819532909
# Sensitivity :  0.6987951807228916

# %% [markdown]
# ## Ensemble with intermediate layers of loaded models

# %%
intermediate_layer_model1 = keras.Model(inputs=model1.input,
                                       outputs=model1.get_layer("dense").output)
intermediate_layer_model3 = keras.Model(inputs=model3.input,
                                       outputs=model3.get_layer("dense").output)
intermediate_layer_model4 = keras.Model(inputs=model4.input,
                                       outputs=model4.get_layer("dense").output)

intermediate_layer_model1.save(os.path.join(MODEL_PATH, 'model7_pretrained_layers.h5'))
intermediate_layer_model3.save(os.path.join(MODEL_PATH, 'inception_layers.h5'))
intermediate_layer_model4.save(os.path.join(MODEL_PATH, 'resnet_layers.h5'))

# %% [markdown]
# ### Dense layer

# %%
set_seed()

def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
      # make prediction
      pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
      if pred.shape[1] == 128:
          pred = np.hstack((pred, pred, pred, pred))
         
      # stack predictions into [rows, members, probabilities]
      if stackX is None:
        stackX = pred
      else:
        stackX = dstack((stackX, pred))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy, valid_images, valid_labels):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    stacked_valid = stacked_dataset(members, valid_images)
    # fit standalone model
    model = models.Sequential()
    model.add(layers.Dense(1, input_dim=1536, activation='sigmoid'))
    class_weights = class_weight.compute_class_weight('balanced', np.unique(train_labels), train_labels)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    model_checkpoint = ModelCheckpoint(os.path.join(MODEL_PATH, 'model1_pretrained_best.h5'), monitor='val_loss', mode='min', verbose=1, save_best_only=True) #, save_weights_only=True)
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=50)
    history = model.fit(stackedX, inputy, epochs=50, validation_data=(stacked_valid, valid_labels), callbacks = [callback, model_checkpoint], class_weight = dict(enumerate(class_weights)))
    
    performance_plot(history, model)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict(stackedX)
	return pred

members=[{'model': intermediate_layer_model1, 'preprocess': scratch_preprocessing}, 
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
model1 = fit_stacked_model(members, train_images, train_labels, valid_images, valid_labels)

model1.save(os.path.join(MODEL_PATH, 'model1_pretrained.h5'))
best_model1 = models.load_model(os.path.join(MODEL_PATH, 'model1_pretrained_best.h5'))

train_pred = stacked_prediction(members, best_model1, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate model1 on test set
pred = stacked_prediction(members, best_model1, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, best_model1, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Epoch 1/50
# 59/59 [==============================] - 1s 6ms/step - loss: 0.7152 - acc: 0.5949 - val_loss: 0.4962 - val_acc: 0.7323
#
# Epoch 00001: val_loss improved from inf to 0.49620, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 2/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4552 - acc: 0.7882 - val_loss: 0.4837 - val_acc: 0.7447
#
# Epoch 00002: val_loss improved from 0.49620 to 0.48365, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 3/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4220 - acc: 0.7968 - val_loss: 0.4794 - val_acc: 0.7509
#
# Epoch 00003: val_loss improved from 0.48365 to 0.47938, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 4/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4390 - acc: 0.7780 - val_loss: 0.4811 - val_acc: 0.7572
#
# Epoch 00004: val_loss did not improve from 0.47938
# Epoch 5/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4162 - acc: 0.7977 - val_loss: 0.4764 - val_acc: 0.7559
#
# Epoch 00005: val_loss improved from 0.47938 to 0.47637, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 6/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4299 - acc: 0.7918 - val_loss: 0.4763 - val_acc: 0.7572
#
# Epoch 00006: val_loss improved from 0.47637 to 0.47633, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 7/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3841 - acc: 0.8147 - val_loss: 0.4759 - val_acc: 0.7609
#
# Epoch 00007: val_loss improved from 0.47633 to 0.47590, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model1_pretrained_best.h5
# Epoch 8/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4263 - acc: 0.7864 - val_loss: 0.4770 - val_acc: 0.7696
#
# Epoch 00008: val_loss did not improve from 0.47590
# Epoch 9/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4214 - acc: 0.7947 - val_loss: 0.4770 - val_acc: 0.7634
#
# Epoch 00009: val_loss did not improve from 0.47590
# Epoch 10/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4006 - acc: 0.8089 - val_loss: 0.4795 - val_acc: 0.7584
#
# Epoch 00010: val_loss did not improve from 0.47590
# Epoch 11/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3932 - acc: 0.8142 - val_loss: 0.4792 - val_acc: 0.7559
#
# Epoch 00011: val_loss did not improve from 0.47590
# Epoch 12/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4092 - acc: 0.7950 - val_loss: 0.4795 - val_acc: 0.7584
#
# Epoch 00012: val_loss did not improve from 0.47590
# Epoch 13/50
# 59/59 [==============================] - 0s 2ms/step - loss: 0.3963 - acc: 0.8057 - val_loss: 0.4782 - val_acc: 0.7584
#
# Epoch 00013: val_loss did not improve from 0.47590
# Epoch 14/50
# 59/59 [==============================] - 0s 2ms/step - loss: 0.4052 - acc: 0.8028 - val_loss: 0.4786 - val_acc: 0.7609
#
# Epoch 00014: val_loss did not improve from 0.47590
# Epoch 15/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4259 - acc: 0.7908 - val_loss: 0.4797 - val_acc: 0.7572
#
# Epoch 00015: val_loss did not improve from 0.47590
# Epoch 16/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4068 - acc: 0.8104 - val_loss: 0.4794 - val_acc: 0.7634
#
# Epoch 00016: val_loss did not improve from 0.47590
# Epoch 17/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3853 - acc: 0.8031 - val_loss: 0.4818 - val_acc: 0.7621
#
# Epoch 00017: val_loss did not improve from 0.47590
# Epoch 18/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4115 - acc: 0.7859 - val_loss: 0.4882 - val_acc: 0.7522
#
# Epoch 00018: val_loss did not improve from 0.47590
# Epoch 19/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4087 - acc: 0.8088 - val_loss: 0.4815 - val_acc: 0.7534
#
# Epoch 00019: val_loss did not improve from 0.47590
# Epoch 20/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4238 - acc: 0.7828 - val_loss: 0.4817 - val_acc: 0.7609
#
# Epoch 00020: val_loss did not improve from 0.47590
# Epoch 21/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3888 - acc: 0.8186 - val_loss: 0.4815 - val_acc: 0.7597
#
# Epoch 00021: val_loss did not improve from 0.47590
# Epoch 22/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4079 - acc: 0.8033 - val_loss: 0.4799 - val_acc: 0.7572
#
# Epoch 00022: val_loss did not improve from 0.47590
# Epoch 23/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4112 - acc: 0.8020 - val_loss: 0.4821 - val_acc: 0.7584
#
# Epoch 00023: val_loss did not improve from 0.47590
# Epoch 24/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4104 - acc: 0.7955 - val_loss: 0.4798 - val_acc: 0.7597
#
# Epoch 00024: val_loss did not improve from 0.47590
# Epoch 25/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4003 - acc: 0.8066 - val_loss: 0.4819 - val_acc: 0.7584
#
# Epoch 00025: val_loss did not improve from 0.47590
# Epoch 26/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4100 - acc: 0.8075 - val_loss: 0.4916 - val_acc: 0.7534
#
# Epoch 00026: val_loss did not improve from 0.47590
# Epoch 27/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4060 - acc: 0.7836 - val_loss: 0.4863 - val_acc: 0.7572
#
# Epoch 00027: val_loss did not improve from 0.47590
# Epoch 28/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4050 - acc: 0.7854 - val_loss: 0.4830 - val_acc: 0.7572
#
# Epoch 00028: val_loss did not improve from 0.47590
# Epoch 29/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3966 - acc: 0.8044 - val_loss: 0.4829 - val_acc: 0.7609
#
# Epoch 00029: val_loss did not improve from 0.47590
# Epoch 30/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4005 - acc: 0.8145 - val_loss: 0.4829 - val_acc: 0.7559
#
# Epoch 00030: val_loss did not improve from 0.47590
# Epoch 31/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4136 - acc: 0.7976 - val_loss: 0.4891 - val_acc: 0.7509
#
# Epoch 00031: val_loss did not improve from 0.47590
# Epoch 32/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4021 - acc: 0.8071 - val_loss: 0.4836 - val_acc: 0.7659
#
# Epoch 00032: val_loss did not improve from 0.47590
# Epoch 33/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4052 - acc: 0.8004 - val_loss: 0.4839 - val_acc: 0.7584
#
# Epoch 00033: val_loss did not improve from 0.47590
# Epoch 34/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3927 - acc: 0.8069 - val_loss: 0.4877 - val_acc: 0.7634
#
# Epoch 00034: val_loss did not improve from 0.47590
# Epoch 35/50
# 59/59 [==============================] - 0s 5ms/step - loss: 0.4267 - acc: 0.7899 - val_loss: 0.4916 - val_acc: 0.7534
#
# Epoch 00035: val_loss did not improve from 0.47590
# Epoch 36/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3963 - acc: 0.8020 - val_loss: 0.4851 - val_acc: 0.7597
#
# Epoch 00036: val_loss did not improve from 0.47590
# Epoch 37/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3956 - acc: 0.8057 - val_loss: 0.4836 - val_acc: 0.7584
#
# Epoch 00037: val_loss did not improve from 0.47590
# Epoch 38/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3935 - acc: 0.8074 - val_loss: 0.4828 - val_acc: 0.7634
#
# Epoch 00038: val_loss did not improve from 0.47590
# Epoch 39/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3847 - acc: 0.8112 - val_loss: 0.4852 - val_acc: 0.7584
#
# Epoch 00039: val_loss did not improve from 0.47590
# Epoch 40/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3902 - acc: 0.8049 - val_loss: 0.4848 - val_acc: 0.7597
#
# Epoch 00040: val_loss did not improve from 0.47590
# Epoch 41/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4131 - acc: 0.8069 - val_loss: 0.4855 - val_acc: 0.7609
#
# Epoch 00041: val_loss did not improve from 0.47590
# Epoch 42/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3973 - acc: 0.8048 - val_loss: 0.4857 - val_acc: 0.7659
#
# Epoch 00042: val_loss did not improve from 0.47590
# Epoch 43/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4191 - acc: 0.7996 - val_loss: 0.4855 - val_acc: 0.7659
#
# Epoch 00043: val_loss did not improve from 0.47590
# Epoch 44/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3968 - acc: 0.8054 - val_loss: 0.4848 - val_acc: 0.7621
#
# Epoch 00044: val_loss did not improve from 0.47590
# Epoch 45/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4024 - acc: 0.7973 - val_loss: 0.4857 - val_acc: 0.7634
#
# Epoch 00045: val_loss did not improve from 0.47590
# Epoch 46/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3910 - acc: 0.8137 - val_loss: 0.4882 - val_acc: 0.7547
#
# Epoch 00046: val_loss did not improve from 0.47590
# Epoch 47/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4171 - acc: 0.7918 - val_loss: 0.4851 - val_acc: 0.7621
#
# Epoch 00047: val_loss did not improve from 0.47590
# Epoch 48/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4188 - acc: 0.7954 - val_loss: 0.4870 - val_acc: 0.7634
#
# Epoch 00048: val_loss did not improve from 0.47590
# Epoch 49/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3852 - acc: 0.8198 - val_loss: 0.4864 - val_acc: 0.7621
#
# Epoch 00049: val_loss did not improve from 0.47590
# Epoch 50/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.3819 - acc: 0.8128 - val_loss: 0.4860 - val_acc: 0.7646
#
# Epoch 00050: val_loss did not improve from 0.47590
# Stacked Train Accuracy: 0.800
# Stacked Test Accuracy: 0.685
# Specificity :  0.6575342465753424
# Sensitivity :  0.7350427350427351
# Result: f2_score=0.684
# Stacked Valid Accuracy: 0.761
# Specificity :  0.7876857749469215
# Sensitivity :  0.7228915662650602

# %% [markdown]
# ### Dense layer and dropout

# %%
set_seed()

def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
      # make prediction
      pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
      if pred.shape[1] == 128:
          pred = np.hstack((pred, pred, pred, pred))
      # stack predictions into [rows, members, probabilities]
      if stackX is None:
        stackX = pred
      else:
        stackX = dstack((stackX, pred))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy, valid_images, valid_labels):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    stacked_valid = stacked_dataset(members, valid_images)
    # fit standalone model
    model = models.Sequential()
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, input_dim=1536, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    class_weights = class_weight.compute_class_weight('balanced', np.unique(train_labels), train_labels)
    model_checkpoint = ModelCheckpoint(os.path.join(MODEL_PATH, 'model2_pretrained_best.h5'), monitor='val_loss', mode='min', verbose=1, save_best_only=True) #, save_weights_only=True)
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=50)
    history = model.fit(stackedX, inputy, epochs=50, validation_data=(stacked_valid, valid_labels), callbacks = [callback, model_checkpoint], class_weight = dict(enumerate(class_weights)))
    
    performance_plot(history, model)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict(stackedX)
	return pred

members=[{'model': intermediate_layer_model1, 'preprocess': scratch_preprocessing}, 
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
model2 = fit_stacked_model(members, train_images, train_labels, valid_images, valid_labels)

model2.save(os.path.join(MODEL_PATH, 'model2_pretrained.h5'))
best_model2 = models.load_model(os.path.join(MODEL_PATH, 'model2_pretrained_best.h5'))

train_pred = stacked_prediction(members, best_model2, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate model2 on test set
pred = stacked_prediction(members, best_model2, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels) 

valid_pred = stacked_prediction(members, best_model2, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Epoch 1/50
# 59/59 [==============================] - 1s 10ms/step - loss: 0.8032 - acc: 0.5823 - val_loss: 0.5013 - val_acc: 0.7372
#
# Epoch 00001: val_loss improved from inf to 0.50132, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 2/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5530 - acc: 0.7075 - val_loss: 0.4860 - val_acc: 0.7460
#
# Epoch 00002: val_loss improved from 0.50132 to 0.48598, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 3/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5167 - acc: 0.7390 - val_loss: 0.4785 - val_acc: 0.7460
#
# Epoch 00003: val_loss improved from 0.48598 to 0.47847, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 4/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4966 - acc: 0.7372 - val_loss: 0.4810 - val_acc: 0.7447
#
# Epoch 00004: val_loss did not improve from 0.47847
# Epoch 5/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4837 - acc: 0.7606 - val_loss: 0.4735 - val_acc: 0.7522
#
# Epoch 00005: val_loss improved from 0.47847 to 0.47347, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 6/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4868 - acc: 0.7641 - val_loss: 0.4702 - val_acc: 0.7522
#
# Epoch 00006: val_loss improved from 0.47347 to 0.47017, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 7/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4721 - acc: 0.7505 - val_loss: 0.4678 - val_acc: 0.7497
#
# Epoch 00007: val_loss improved from 0.47017 to 0.46783, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 8/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4935 - acc: 0.7393 - val_loss: 0.4677 - val_acc: 0.7522
#
# Epoch 00008: val_loss improved from 0.46783 to 0.46772, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 9/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4910 - acc: 0.7421 - val_loss: 0.4677 - val_acc: 0.7472
#
# Epoch 00009: val_loss improved from 0.46772 to 0.46772, saving model to /content/drive/Shareddrives/Verna_Minutella_Veltroni/models/models_task5_2/model2_pretrained_best.h5
# Epoch 10/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4636 - acc: 0.7631 - val_loss: 0.4705 - val_acc: 0.7497
#
# Epoch 00010: val_loss did not improve from 0.46772
# Epoch 11/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4716 - acc: 0.7565 - val_loss: 0.4711 - val_acc: 0.7497
#
# Epoch 00011: val_loss did not improve from 0.46772
# Epoch 12/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4847 - acc: 0.7406 - val_loss: 0.4744 - val_acc: 0.7497
#
# Epoch 00012: val_loss did not improve from 0.46772
# Epoch 13/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4703 - acc: 0.7559 - val_loss: 0.4698 - val_acc: 0.7497
#
# Epoch 00013: val_loss did not improve from 0.46772
# Epoch 14/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4642 - acc: 0.7671 - val_loss: 0.4719 - val_acc: 0.7522
#
# Epoch 00014: val_loss did not improve from 0.46772
# Epoch 15/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4919 - acc: 0.7464 - val_loss: 0.4744 - val_acc: 0.7522
#
# Epoch 00015: val_loss did not improve from 0.46772
# Epoch 16/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4831 - acc: 0.7587 - val_loss: 0.4687 - val_acc: 0.7484
#
# Epoch 00016: val_loss did not improve from 0.46772
# Epoch 17/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4517 - acc: 0.7617 - val_loss: 0.4715 - val_acc: 0.7522
#
# Epoch 00017: val_loss did not improve from 0.46772
# Epoch 18/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4867 - acc: 0.7415 - val_loss: 0.4821 - val_acc: 0.7447
#
# Epoch 00018: val_loss did not improve from 0.46772
# Epoch 19/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4884 - acc: 0.7318 - val_loss: 0.4770 - val_acc: 0.7447
#
# Epoch 00019: val_loss did not improve from 0.46772
# Epoch 20/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4887 - acc: 0.7377 - val_loss: 0.4723 - val_acc: 0.7484
#
# Epoch 00020: val_loss did not improve from 0.46772
# Epoch 21/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4748 - acc: 0.7668 - val_loss: 0.4735 - val_acc: 0.7509
#
# Epoch 00021: val_loss did not improve from 0.46772
# Epoch 22/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4914 - acc: 0.7527 - val_loss: 0.4710 - val_acc: 0.7447
#
# Epoch 00022: val_loss did not improve from 0.46772
# Epoch 23/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4847 - acc: 0.7467 - val_loss: 0.4690 - val_acc: 0.7472
#
# Epoch 00023: val_loss did not improve from 0.46772
# Epoch 24/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4791 - acc: 0.7537 - val_loss: 0.4728 - val_acc: 0.7460
#
# Epoch 00024: val_loss did not improve from 0.46772
# Epoch 25/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4687 - acc: 0.7566 - val_loss: 0.4704 - val_acc: 0.7497
#
# Epoch 00025: val_loss did not improve from 0.46772
# Epoch 26/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4844 - acc: 0.7656 - val_loss: 0.4805 - val_acc: 0.7422
#
# Epoch 00026: val_loss did not improve from 0.46772
# Epoch 27/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4681 - acc: 0.7310 - val_loss: 0.4725 - val_acc: 0.7522
#
# Epoch 00027: val_loss did not improve from 0.46772
# Epoch 28/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4650 - acc: 0.7444 - val_loss: 0.4731 - val_acc: 0.7509
#
# Epoch 00028: val_loss did not improve from 0.46772
# Epoch 29/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4647 - acc: 0.7607 - val_loss: 0.4693 - val_acc: 0.7559
#
# Epoch 00029: val_loss did not improve from 0.46772
# Epoch 30/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4606 - acc: 0.7608 - val_loss: 0.4683 - val_acc: 0.7547
#
# Epoch 00030: val_loss did not improve from 0.46772
# Epoch 31/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4905 - acc: 0.7384 - val_loss: 0.4779 - val_acc: 0.7460
#
# Epoch 00031: val_loss did not improve from 0.46772
# Epoch 32/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4652 - acc: 0.7499 - val_loss: 0.4708 - val_acc: 0.7509
#
# Epoch 00032: val_loss did not improve from 0.46772
# Epoch 33/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4659 - acc: 0.7581 - val_loss: 0.4687 - val_acc: 0.7522
#
# Epoch 00033: val_loss did not improve from 0.46772
# Epoch 34/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4574 - acc: 0.7761 - val_loss: 0.4709 - val_acc: 0.7472
#
# Epoch 00034: val_loss did not improve from 0.46772
# Epoch 35/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5207 - acc: 0.7221 - val_loss: 0.4762 - val_acc: 0.7522
#
# Epoch 00035: val_loss did not improve from 0.46772
# Epoch 36/50
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4777 - acc: 0.7557 - val_loss: 0.4730 - val_acc: 0.7497
#
# Epoch 00036: val_loss did not improve from 0.46772
# Epoch 37/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4737 - acc: 0.7511 - val_loss: 0.4698 - val_acc: 0.7547
#
# Epoch 00037: val_loss did not improve from 0.46772
# Epoch 38/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4746 - acc: 0.7439 - val_loss: 0.4717 - val_acc: 0.7547
#
# Epoch 00038: val_loss did not improve from 0.46772
# Epoch 39/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4721 - acc: 0.7521 - val_loss: 0.4719 - val_acc: 0.7509
#
# Epoch 00039: val_loss did not improve from 0.46772
# Epoch 40/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4858 - acc: 0.7446 - val_loss: 0.4773 - val_acc: 0.7497
#
# Epoch 00040: val_loss did not improve from 0.46772
# Epoch 41/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.5031 - acc: 0.7366 - val_loss: 0.4718 - val_acc: 0.7547
#
# Epoch 00041: val_loss did not improve from 0.46772
# Epoch 42/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4657 - acc: 0.7535 - val_loss: 0.4741 - val_acc: 0.7547
#
# Epoch 00042: val_loss did not improve from 0.46772
# Epoch 43/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4797 - acc: 0.7553 - val_loss: 0.4723 - val_acc: 0.7460
#
# Epoch 00043: val_loss did not improve from 0.46772
# Epoch 44/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4713 - acc: 0.7714 - val_loss: 0.4699 - val_acc: 0.7484
#
# Epoch 00044: val_loss did not improve from 0.46772
# Epoch 45/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4704 - acc: 0.7463 - val_loss: 0.4705 - val_acc: 0.7534
#
# Epoch 00045: val_loss did not improve from 0.46772
# Epoch 46/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4721 - acc: 0.7578 - val_loss: 0.4754 - val_acc: 0.7522
#
# Epoch 00046: val_loss did not improve from 0.46772
# Epoch 47/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4826 - acc: 0.7531 - val_loss: 0.4762 - val_acc: 0.7497
#
# Epoch 00047: val_loss did not improve from 0.46772
# Epoch 48/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4985 - acc: 0.7457 - val_loss: 0.4735 - val_acc: 0.7460
#
# Epoch 00048: val_loss did not improve from 0.46772
# Epoch 49/50
# 59/59 [==============================] - 0s 3ms/step - loss: 0.4718 - acc: 0.7519 - val_loss: 0.4744 - val_acc: 0.7522
#
# Epoch 00049: val_loss did not improve from 0.46772
# Epoch 50/50
# 59/59 [==============================] - 0s 4ms/step - loss: 0.4529 - acc: 0.7679 - val_loss: 0.4736 - val_acc: 0.7522
#
# Epoch 00050: val_loss did not improve from 0.46772
# Stacked Train Accuracy: 0.784
# Stacked Test Accuracy: 0.682
# Specificity :  0.6438356164383562
# Sensitivity :  0.7521367521367521
# Result: f2_score=0.694
# Stacked Valid Accuracy: 0.747
# Specificity :  0.7494692144373672
# Sensitivity :  0.7439759036144579

# %% [markdown]
# ### Logistic Regression

# %%
set_seed()

def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
      # make prediction
      pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
      if pred.shape[1] == 128:
          pred = np.hstack((pred, pred, pred, pred))
      # stack predictions into [rows, members, probabilities]
      if stackX is None:
        stackX = pred
      else:
        stackX = dstack((stackX, pred))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
      # create dataset using ensemble
      stackedX = stacked_dataset(members, inputX)
      # fit standalone model
      model = LogisticRegression(max_iter=600, random_state=13, class_weight='balanced')
      model.fit(stackedX, inputy)
      return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': intermediate_layer_model1, 'preprocess': scratch_preprocessing}, 
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble4 = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble4, os.path.join(MODEL_PATH, 'logreg_pretrained_layers.h5'))

train_pred = stacked_prediction(members, ensemble4, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble4 on test set
pred = stacked_prediction(members, ensemble4, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble4, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Stacked Train Accuracy: 0.817
# Stacked Test Accuracy: 0.661
# Specificity :  0.6027397260273972
# Sensitivity :  0.7692307692307693
# Result: f2_score=0.698
# Stacked Valid Accuracy: 0.756
# Specificity :  0.7770700636942676
# Sensitivity :  0.7259036144578314

# %% [markdown]
# ### LinearSVC

# %%
set_seed()

def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
      # make prediction
      pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
      if pred.shape[1] == 128:
          pred = np.hstack((pred, pred, pred, pred))
      # stack predictions into [rows, members, probabilities]
      if stackX is None:
        stackX = pred
      else:
        stackX = dstack((stackX, pred))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # fit standalone model
    model = CalibratedClassifierCV(base_estimator=LinearSVC(max_iter=800, random_state=13, class_weight='balanced'))
    model.fit(stackedX, inputy)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': intermediate_layer_model1, 'preprocess': scratch_preprocessing}, 
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble5 = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble5, os.path.join(MODEL_PATH, 'lsvc_pretrained_layers.h5'))

train_pred = stacked_prediction(members, ensemble5, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble5 on test set
pred = stacked_prediction(members, ensemble5, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble5, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Stacked Train Accuracy: 0.819
# Stacked Test Accuracy: 0.693
# Specificity :  0.6986301369863014
# Sensitivity :  0.6837606837606838
# Result: f2_score=0.651
# Stacked Valid Accuracy: 0.752
# Specificity :  0.8259023354564756
# Sensitivity :  0.6475903614457831

# %% [markdown]
# ### SVC

# %%
set_seed()

def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
      # make prediction
      pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
      if pred.shape[1] == 128:
          pred = np.hstack((pred, pred, pred, pred))
      # stack predictions into [rows, members, probabilities]
      if stackX is None:
        stackX = pred
      else:
        stackX = dstack((stackX, pred))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # fit standalone model
    model = SVC(probability=True, random_state=13, class_weight='balanced')
    model.fit(stackedX, inputy)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[{'model': intermediate_layer_model1, 'preprocess': scratch_preprocessing}, 
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble6 = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble6, os.path.join(MODEL_PATH, 'svc_pretrained_layers.h5'))

train_pred = stacked_prediction(members, ensemble6, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble6 on test set
pred = stacked_prediction(members, ensemble6, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble6, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# Stacked Train Accuracy: 0.799
# Stacked Test Accuracy: 0.693
# Specificity :  0.726027397260274
# Sensitivity :  0.6324786324786325
# Result: f2_score=0.615
# Stacked Valid Accuracy: 0.760
# Specificity :  0.8343949044585988
# Sensitivity :  0.6536144578313253

# %% [markdown]
# ### Only pretrained

# %%
set_seed()

# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = pred
		else:
			stackX = dstack((stackX, pred))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # fit standalone model
    model = LogisticRegression(max_iter=500, random_state=13, class_weight='balanced')
    model.fit(stackedX, inputy)
    return model

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

members=[
         {'model': intermediate_layer_model4, 'preprocess': resnet_preprocess},
         {'model': intermediate_layer_model3, 'preprocess': inception_preprocess}]

# fit stacked model using the ensemble
ensemble = fit_stacked_model(members, train_images, train_labels)

joblib.dump(ensemble, os.path.join(MODEL_PATH, '_pretrained.h5'))

train_pred = stacked_prediction(members, ensemble, train_images)
train_acc = accuracy_score(train_labels, np.rint(train_pred))
print('Stacked Train Accuracy: %.3f' % train_acc)

# evaluate ensemble on test set
pred = stacked_prediction(members, ensemble, test_images)
acc = accuracy_score(test_labels, np.rint(pred))
print('Stacked Test Accuracy: %.3f' % acc)

cm = confusion_matrix(test_labels, np.rint(pred))
plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')
plot_roc_curve(pred, test_labels)

valid_pred = stacked_prediction(members, ensemble, valid_images)
valid_acc = accuracy_score(valid_labels, np.rint(valid_pred))
print('Stacked Valid Accuracy: %.3f' % valid_acc)

cm_valid = confusion_matrix(valid_labels, np.rint(valid_pred))
plot_confusion_matrix(cm_valid, classes=[0,1], normalize=False, title='Confusion matrix')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Stacked Train Accuracy: 0.809
# Stacked Test Accuracy: 0.661
# Specificity :  0.6027397260273972
# Sensitivity :  0.7692307692307693
# Result: f2_score=0.698
# Stacked Valid Accuracy: 0.760
# Specificity :  0.7770700636942676
# Sensitivity :  0.7349397590361446

# %% [markdown]
# ## Error Analysis

# %%
import seaborn as sns

def get_errors(pred):
    errors = []
    mispred = []

    for l, p, img in zip(test_labels, pred, test_images):
        err = abs(l-p)
        errors.append(err)
        c = 1 if p>0.5 else 0
        if l == 1 and c== 0 and err > 0.5:
            mispred.append((l,p,img))

    return errors, mispred

def show_error_stats(errors, mispred):

    print("Number of test images: %d" % len(test_labels))
    print("Mispredictions: %d" % len(mispred))

    for l,p,img in mispred:
        plt.figure()
        plt.imshow(img[:,:,0], cmap='gray')
        plt.title('Misclassified as ' + ('benign' if l==1 else 'malignant') + ' with %.2f confidence' % (100*abs(p-l)))
        #plt.axis('off')
        

def stacked_dataset(members, inputX):
	stackX = None
	for model in members:
		# make prediction
		pred = model['model'].predict(model['preprocess'](inputX), verbose=0)
		# stack predictions into [rows, members, probabilities]
		if stackX is None:
			stackX = pred
		else:
			stackX = dstack((stackX, pred))
	# flatten predictions to [rows, members x probabilities]
	stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
	return stackX

def stacked_prediction(members, model, inputX):
	# create dataset using ensemble
	stackedX = stacked_dataset(members, inputX)
	# make a prediction
	pred = model.predict_proba(stackedX)[:,1]
	return pred

model = joblib.load(os.path.join(DIR_PATH, 'models/models_task5_2/logreg_pretrained.h5'))
model1 = models.load_model(os.path.join(DIR_PATH, 'models/models_task2_2/model7_best.h5'))
model3 = models.load_model(os.path.join(DIR_PATH, 'models/models_task3_2/inception4_best.h5'))
model4 = models.load_model(os.path.join(DIR_PATH, 'models/models_task3_2/resnet3_best.h5'))

members=[{'model': model1, 'preprocess': scratch_preprocessing}, 
         {'model': model4, 'preprocess': resnet_preprocess},
         {'model': model3, 'preprocess': inception_preprocess}]

test_pred = stacked_prediction(members, model, test_images)
errors, mispred = get_errors(test_pred)
show_error_stats(errors, mispred)
# Out:
# Number of test images: 336
# Mispredictions: 26
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
