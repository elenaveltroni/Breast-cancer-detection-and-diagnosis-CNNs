# %% [markdown]
# ## TASK 4
# Development of a classification model for discriminating the abnormality type  the diagnosis (benign v malignant), using pre-trained or from-scratch CNN. The model must exploit the baseline patches (e.g. feeding model with both abnormality and baseline patches, siamese architecture, ...)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %tensorflow_version 2.x
import os
import itertools
import numpy as np
import tensorflow as tf
import random as rn
import matplotlib.pyplot as plt
from tensorflow.compat.v1.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, classification_report
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
# Parameters
DIR_PATH = '/content/drive/Shareddrives/Verna_Minutella_Veltroni'
MODEL_PATH = os.path.join(DIR_PATH, 'models/models_task4_2') 
NUMPY_PATH = os.path.join(DIR_PATH, 'numpy_data')

BATCH_SIZE = 128

# Set seed for reproducibility
tf.keras.backend.clear_session()

seed_num = 1
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed_num)
rn.seed(seed_num)
tf.random.set_seed(seed_num)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# ### Utility function definition

# %% [markdown]
# #### Loading training and test sets

# %%
# Loading training set and test set
def load_training():
  images = np.load(os.path.join(NUMPY_PATH,'train_tensor.npy'))
  labels = np.load(os.path.join(NUMPY_PATH,'train_labels.npy'))
  return images, labels

def load_test():
  images = np.load(os.path.join(NUMPY_PATH,'public_test_tensor.npy'))
  labels = np.load(os.path.join(NUMPY_PATH,'public_test_labels.npy'))
  return images, labels

# %% [markdown]
# #### Plotting the confusion matrix

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    specificity = cm[0,0]/(cm[0,0]+cm[0,1])
    print('Specificity : ', specificity )

    sensitivity = cm[1,1]/(cm[1,0]+cm[1,1])
    print('Sensitivity : ', sensitivity)
    plt.show()

# %% [markdown]
# #### Plotting accuracy and loss trends

# %%
# Utility function for plotting accuracy and loss function
def performance_plot(history, model, test_generator, test_labels):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'r', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  fig1 = plt.figure()

  plt.plot(epochs, loss, 'r', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

  pred_labels = model.predict(test_generator)
  pred_labels = np.rint(pred_labels)
  cm = confusion_matrix(test_labels, pred_labels)
  plot_confusion_matrix(cm, classes=[0,1], normalize=False, title='Confusion matrix')

  print(classification_report(test_labels, pred_labels, digits=4))
  probs = model.predict(test_generator)
  
  fig2 = plt.figure()
  fpr, tpr, threshold = roc_curve(test_labels, probs)
  roc_auc = auc(fpr, tpr) 
  plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
  plt.legend(loc = 'lower right')
  plt.plot([0, 1], [0, 1],'r--')
  plt.xlim([0, 1])
  plt.ylim([0, 1])
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.show()
  f = fbeta_score(test_labels, np.rint(probs), beta=2.0)
  print('Result: f2_score=%.3f' % (f))

# %% [markdown]
# ### Dataset creation
# We take the original dataset with five labels: we discard the label '0', which correspond to baseline patch, because we are considering only the abnormalities, and we aggregate label '1' and '2', which both correspond to masses, and label '3' and '4', which are both calcifications.

# %%
train_img, train_lab = load_training()
test_img, test_lab = load_test()

# Training set
abnormality_images = train_img[1::2] 
abnormality_labels = train_lab[1::2]

base_images = train_img[0::2].reshape((2676, 150, 150, 1)).astype('float32') / 65535

abnormality_images = abnormality_images.reshape((2676, 150, 150, 1)) 
abnormality_images = abnormality_images.astype('float32') / 65535

abnormality_labels[abnormality_labels == 1] = 0
abnormality_labels[abnormality_labels == 2] = 1
abnormality_labels[abnormality_labels == 3] = 0
abnormality_labels[abnormality_labels == 4] = 1

print("Original training set")
print(abnormality_labels.shape)
print(abnormality_images.shape)

# join base image and abnormaliy images
abnormality_images = np.expand_dims(abnormality_images, axis=1)
base_images = np.expand_dims(base_images, axis=1)
abnormality_images = np.hstack((abnormality_images, base_images))
print("After joining with base images")
print(abnormality_images.shape)

# Validation set
train_images, valid_images, train_labels, valid_labels = train_test_split(abnormality_images, abnormality_labels, test_size=0.30, random_state=42, stratify=abnormality_labels)

print("Training set")
print(train_labels.shape)
print(train_images.shape)
print("Validation set")
print(valid_labels.shape)
print(valid_images.shape)


# Test set
test_images = test_img[1::2]
test_labels = test_lab[1::2]
test_base_images = test_img[0::2].reshape((336, 150, 150, 1)).astype('float32') / 65535

test_images = test_images.reshape((336, 150, 150, 1))
test_images = test_images.astype('float32') / 65535

test_labels[test_labels == 1] = 0
test_labels[test_labels == 2] = 1
test_labels[test_labels == 3] = 0
test_labels[test_labels == 4] = 1


print("Test set")
print(test_labels.shape)
print(test_images.shape)

# join base image and abnormaliy images
test_images = np.expand_dims(test_images, axis=1)
test_base_images = np.expand_dims(test_base_images, axis=1)
test_images = np.hstack((test_images, test_base_images))
print("After joining with base images")
print(test_images.shape)

class_weights = class_weight.compute_class_weight('balanced', np.unique(train_labels), train_labels)
class_weights = dict(enumerate(class_weights))
# Out:
# Original training set
# (2676,)
# (2676, 150, 150, 1)
# After joining with base images
# (2676, 2, 150, 150, 1)
# Training set
# (1873,)
# (1873, 2, 150, 150, 1)
# Validation set
# (803,)
# (803, 2, 150, 150, 1)
# Test set
# (336,)
# (336, 150, 150, 1)
# After joining with base images
# (336, 2, 150, 150, 1)

# %% [markdown]
# ### Siamese Network

# %% [markdown]
# #### Preprocessing
# We perform Data Augmentation with the training set in order to increase the number of data.
#
# We consider geometric transformations, such as the rotation, the vertical and horizontal flip. We choose as fill mode the default value which fills the area with the nearest pixel and stretching it.
#
# The rescaling is made to 65535 because the dataset is composed by 16 bit images.

# %%
def get_data_gen(data, labels, data_gen_args = {}, seed = 1):
  datagen_abnormality = ImageDataGenerator(**data_gen_args)
  # Provide the same seed and keyword arguments to the fit and flow methods
  datagen_abnormality.fit(data[:,0,:,:,:], seed=seed)


  generator_abnormality = datagen_abnormality.flow(data[:,0,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)
  generator_base = datagen_abnormality.flow(data[:,1,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)

  # combine generators into one which yields image and masks
  while True:
    abnormality_image, label = generator_abnormality.next()
    base_image, _ = generator_base.next()
    yield [abnormality_image, base_image], label

# %%
train_datagen_args = dict(
    rotation_range=180,
    vertical_flip = True,
    horizontal_flip = True)

train_generator = get_data_gen(train_images, train_labels, train_datagen_args)

validation_generator = get_data_gen(valid_images, valid_labels)

# %% [markdown]
# #### Experiment 1

# %%
input_shape = (150, 150, 1)
# Two input channels
left_input = layers.Input(shape=input_shape)
right_input = layers.Input(shape=input_shape)

# CNN core
cnn = models.Sequential()
cnn.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(128, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(128, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(4096, activation='sigmoid'))

# Feed both input into the same convolutional base
left_model = cnn(left_input)
right_model = cnn(right_input)

L1_layer = layers.Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
L1_distance = L1_layer([left_model, right_model])

# Add a dense layer with a sigmoid unit to generate the similarity score
prediction = layers.Dense(1, activation='sigmoid')(L1_distance)


# Instantiate the model
siamese = models.Model(inputs=[left_input, right_input], outputs=prediction)
siamese.summary()
siamese.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=0.0001),
              metrics=['acc'])

model_checkpoint = ModelCheckpoint('checkpoint.h5', save_best_only=True, save_weights_only=True, verbose=1)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_acc', patience=50)

history = siamese.fit(
  train_generator,
  steps_per_epoch = len(train_images) // BATCH_SIZE,
  epochs=150,
  class_weight = class_weights,
  validation_data = validation_generator,
  validation_steps =  len(valid_images) // BATCH_SIZE,
  callbacks = [callback, model_checkpoint]
  )
siamese.load_weights('checkpoint.h5')
performance_plot(history, siamese, [test_images[:,0,:,:,:], test_images[:,1,:,:,:]], test_labels)
models.save_model(siamese, os.path.join(MODEL_PATH, 'siamese_1.h5'))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 4096)         2378432     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 4096)         0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            4097        lambda[0][0]
# ==================================================================================================
# Total params: 2,382,529
# Trainable params: 2,382,529
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 14/14 [==============================] - 14s 453ms/step - loss: 0.6918 - acc: 0.5314 - val_loss: 0.6933 - val_acc: 0.4310
#
# Epoch 00001: val_loss improved from inf to 0.69329, saving model to checkpoint.h5
# Epoch 2/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6932 - acc: 0.4378 - val_loss: 0.6952 - val_acc: 0.4310
#
# Epoch 00002: val_loss did not improve from 0.69329
# Epoch 3/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6842 - acc: 0.4134 - val_loss: 0.6965 - val_acc: 0.4414
#
# Epoch 00003: val_loss did not improve from 0.69329
# Epoch 4/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6919 - acc: 0.4484 - val_loss: 0.6911 - val_acc: 0.4987
#
# Epoch 00004: val_loss improved from 0.69329 to 0.69115, saving model to checkpoint.h5
# Epoch 5/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6886 - acc: 0.4598 - val_loss: 0.6908 - val_acc: 0.4948
#
# Epoch 00005: val_loss improved from 0.69115 to 0.69084, saving model to checkpoint.h5
# Epoch 6/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6858 - acc: 0.5126 - val_loss: 0.6914 - val_acc: 0.5000
#
# Epoch 00006: val_loss did not improve from 0.69084
# Epoch 7/150
# 14/14 [==============================] - 6s 415ms/step - loss: 0.6849 - acc: 0.4870 - val_loss: 0.6829 - val_acc: 0.5352
#
# Epoch 00007: val_loss improved from 0.69084 to 0.68286, saving model to checkpoint.h5
# Epoch 8/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6811 - acc: 0.5604 - val_loss: 0.6727 - val_acc: 0.5378
#
# Epoch 00008: val_loss improved from 0.68286 to 0.67271, saving model to checkpoint.h5
# Epoch 9/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6705 - acc: 0.5406 - val_loss: 0.6580 - val_acc: 0.5586
#
# Epoch 00009: val_loss improved from 0.67271 to 0.65801, saving model to checkpoint.h5
# Epoch 10/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6648 - acc: 0.5779 - val_loss: 0.6513 - val_acc: 0.5599
#
# Epoch 00010: val_loss improved from 0.65801 to 0.65128, saving model to checkpoint.h5
# Epoch 11/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6594 - acc: 0.5629 - val_loss: 0.6324 - val_acc: 0.5833
#
# Epoch 00011: val_loss improved from 0.65128 to 0.63243, saving model to checkpoint.h5
# Epoch 12/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6601 - acc: 0.5601 - val_loss: 0.6252 - val_acc: 0.5885
#
# Epoch 00012: val_loss improved from 0.63243 to 0.62523, saving model to checkpoint.h5
# Epoch 13/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6459 - acc: 0.5770 - val_loss: 0.6337 - val_acc: 0.5911
#
# Epoch 00013: val_loss did not improve from 0.62523
# Epoch 14/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6470 - acc: 0.5669 - val_loss: 0.6395 - val_acc: 0.5846
#
# Epoch 00014: val_loss did not improve from 0.62523
# Epoch 15/150
# 14/14 [==============================] - 6s 416ms/step - loss: 0.6576 - acc: 0.5571 - val_loss: 0.6254 - val_acc: 0.5872
#
# Epoch 00015: val_loss did not improve from 0.62523
# Epoch 16/150
# 14/14 [==============================] - 6s 436ms/step - loss: 0.6481 - acc: 0.5898 - val_loss: 0.6257 - val_acc: 0.5859
#
# Epoch 00016: val_loss did not improve from 0.62523
# Epoch 17/150
# 14/14 [==============================] - 6s 431ms/step - loss: 0.6615 - acc: 0.5612 - val_loss: 0.6253 - val_acc: 0.5794
#
# Epoch 00017: val_loss did not improve from 0.62523
# Epoch 18/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6354 - acc: 0.5977 - val_loss: 0.6220 - val_acc: 0.5898
#
# Epoch 00018: val_loss improved from 0.62523 to 0.62200, saving model to checkpoint.h5
# Epoch 19/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6407 - acc: 0.5810 - val_loss: 0.6236 - val_acc: 0.5885
#
# Epoch 00019: val_loss did not improve from 0.62200
# Epoch 20/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6461 - acc: 0.5548 - val_loss: 0.6305 - val_acc: 0.5951
#
# Epoch 00020: val_loss did not improve from 0.62200
# Epoch 21/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6348 - acc: 0.5622 - val_loss: 0.6255 - val_acc: 0.6003
#
# Epoch 00021: val_loss did not improve from 0.62200
# Epoch 22/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6459 - acc: 0.5537 - val_loss: 0.6249 - val_acc: 0.5898
#
# Epoch 00022: val_loss did not improve from 0.62200
# Epoch 23/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6382 - acc: 0.5842 - val_loss: 0.6293 - val_acc: 0.5990
#
# Epoch 00023: val_loss did not improve from 0.62200
# Epoch 24/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6463 - acc: 0.5801 - val_loss: 0.6185 - val_acc: 0.5729
#
# Epoch 00024: val_loss improved from 0.62200 to 0.61853, saving model to checkpoint.h5
# Epoch 25/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6378 - acc: 0.5841 - val_loss: 0.6188 - val_acc: 0.5898
#
# Epoch 00025: val_loss did not improve from 0.61853
# Epoch 26/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6512 - acc: 0.5541 - val_loss: 0.6174 - val_acc: 0.5938
#
# Epoch 00026: val_loss improved from 0.61853 to 0.61742, saving model to checkpoint.h5
# Epoch 27/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6294 - acc: 0.6019 - val_loss: 0.6242 - val_acc: 0.5938
#
# Epoch 00027: val_loss did not improve from 0.61742
# Epoch 28/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6413 - acc: 0.5496 - val_loss: 0.6195 - val_acc: 0.5898
#
# Epoch 00028: val_loss did not improve from 0.61742
# Epoch 29/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6497 - acc: 0.5465 - val_loss: 0.6114 - val_acc: 0.6211
#
# Epoch 00029: val_loss improved from 0.61742 to 0.61136, saving model to checkpoint.h5
# Epoch 30/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6466 - acc: 0.5861 - val_loss: 0.6172 - val_acc: 0.5964
#
# Epoch 00030: val_loss did not improve from 0.61136
# Epoch 31/150
# 14/14 [==============================] - 6s 431ms/step - loss: 0.6394 - acc: 0.5783 - val_loss: 0.6269 - val_acc: 0.5898
#
# Epoch 00031: val_loss did not improve from 0.61136
# Epoch 32/150
# 14/14 [==============================] - 6s 430ms/step - loss: 0.6332 - acc: 0.5522 - val_loss: 0.6191 - val_acc: 0.5951
#
# Epoch 00032: val_loss did not improve from 0.61136
# Epoch 33/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6333 - acc: 0.5691 - val_loss: 0.6257 - val_acc: 0.5807
#
# Epoch 00033: val_loss did not improve from 0.61136
# Epoch 34/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6402 - acc: 0.5683 - val_loss: 0.6127 - val_acc: 0.5977
#
# Epoch 00034: val_loss did not improve from 0.61136
# Epoch 35/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6268 - acc: 0.5957 - val_loss: 0.6162 - val_acc: 0.5964
#
# Epoch 00035: val_loss did not improve from 0.61136
# Epoch 36/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6248 - acc: 0.5848 - val_loss: 0.6106 - val_acc: 0.6120
#
# Epoch 00036: val_loss improved from 0.61136 to 0.61058, saving model to checkpoint.h5
# Epoch 37/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6455 - acc: 0.5727 - val_loss: 0.6138 - val_acc: 0.6081
#
# Epoch 00037: val_loss did not improve from 0.61058
# Epoch 38/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6259 - acc: 0.5740 - val_loss: 0.6176 - val_acc: 0.5964
#
# Epoch 00038: val_loss did not improve from 0.61058
# Epoch 39/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6233 - acc: 0.5976 - val_loss: 0.6080 - val_acc: 0.6107
#
# Epoch 00039: val_loss improved from 0.61058 to 0.60802, saving model to checkpoint.h5
# Epoch 40/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6307 - acc: 0.5651 - val_loss: 0.6069 - val_acc: 0.6237
#
# Epoch 00040: val_loss improved from 0.60802 to 0.60686, saving model to checkpoint.h5
# Epoch 41/150
# 14/14 [==============================] - 6s 427ms/step - loss: 0.6281 - acc: 0.5811 - val_loss: 0.6090 - val_acc: 0.6055
#
# Epoch 00041: val_loss did not improve from 0.60686
# Epoch 42/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6203 - acc: 0.6120 - val_loss: 0.6078 - val_acc: 0.6120
#
# Epoch 00042: val_loss did not improve from 0.60686
# Epoch 43/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6311 - acc: 0.5841 - val_loss: 0.6230 - val_acc: 0.5898
#
# Epoch 00043: val_loss did not improve from 0.60686
# Epoch 44/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6399 - acc: 0.5738 - val_loss: 0.6319 - val_acc: 0.5794
#
# Epoch 00044: val_loss did not improve from 0.60686
# Epoch 45/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6511 - acc: 0.5605 - val_loss: 0.6106 - val_acc: 0.6029
#
# Epoch 00045: val_loss did not improve from 0.60686
# Epoch 46/150
# 14/14 [==============================] - 6s 430ms/step - loss: 0.6311 - acc: 0.5739 - val_loss: 0.6061 - val_acc: 0.6172
#
# Epoch 00046: val_loss improved from 0.60686 to 0.60610, saving model to checkpoint.h5
# Epoch 47/150
# 14/14 [==============================] - 6s 439ms/step - loss: 0.6358 - acc: 0.5685 - val_loss: 0.6091 - val_acc: 0.6224
#
# Epoch 00047: val_loss did not improve from 0.60610
# Epoch 48/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6090 - acc: 0.6044 - val_loss: 0.6158 - val_acc: 0.5990
#
# Epoch 00048: val_loss did not improve from 0.60610
# Epoch 49/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6276 - acc: 0.5722 - val_loss: 0.6124 - val_acc: 0.6055
#
# Epoch 00049: val_loss did not improve from 0.60610
# Epoch 50/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6195 - acc: 0.5972 - val_loss: 0.6140 - val_acc: 0.6107
#
# Epoch 00050: val_loss did not improve from 0.60610
# Epoch 51/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6206 - acc: 0.5937 - val_loss: 0.6114 - val_acc: 0.6068
#
# Epoch 00051: val_loss did not improve from 0.60610
# Epoch 52/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6157 - acc: 0.5824 - val_loss: 0.6148 - val_acc: 0.6042
#
# Epoch 00052: val_loss did not improve from 0.60610
# Epoch 53/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6291 - acc: 0.5838 - val_loss: 0.6173 - val_acc: 0.6081
#
# Epoch 00053: val_loss did not improve from 0.60610
# Epoch 54/150
# 14/14 [==============================] - 6s 427ms/step - loss: 0.6161 - acc: 0.5892 - val_loss: 0.6117 - val_acc: 0.5964
#
# Epoch 00054: val_loss did not improve from 0.60610
# Epoch 55/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6163 - acc: 0.5903 - val_loss: 0.6095 - val_acc: 0.6068
#
# Epoch 00055: val_loss did not improve from 0.60610
# Epoch 56/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6236 - acc: 0.6036 - val_loss: 0.6184 - val_acc: 0.5977
#
# Epoch 00056: val_loss did not improve from 0.60610
# Epoch 57/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6373 - acc: 0.5705 - val_loss: 0.5991 - val_acc: 0.6367
#
# Epoch 00057: val_loss improved from 0.60610 to 0.59914, saving model to checkpoint.h5
# Epoch 58/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6192 - acc: 0.6117 - val_loss: 0.6110 - val_acc: 0.6185
#
# Epoch 00058: val_loss did not improve from 0.59914
# Epoch 59/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6273 - acc: 0.5821 - val_loss: 0.6001 - val_acc: 0.6276
#
# Epoch 00059: val_loss did not improve from 0.59914
# Epoch 60/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6134 - acc: 0.5949 - val_loss: 0.6030 - val_acc: 0.6289
#
# Epoch 00060: val_loss did not improve from 0.59914
# Epoch 61/150
# 14/14 [==============================] - 6s 432ms/step - loss: 0.6339 - acc: 0.5916 - val_loss: 0.6072 - val_acc: 0.6263
#
# Epoch 00061: val_loss did not improve from 0.59914
# Epoch 62/150
# 14/14 [==============================] - 6s 434ms/step - loss: 0.6254 - acc: 0.5961 - val_loss: 0.6200 - val_acc: 0.6133
#
# Epoch 00062: val_loss did not improve from 0.59914
# Epoch 63/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6294 - acc: 0.5929 - val_loss: 0.6063 - val_acc: 0.6263
#
# Epoch 00063: val_loss did not improve from 0.59914
# Epoch 64/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6260 - acc: 0.6168 - val_loss: 0.6025 - val_acc: 0.6302
#
# Epoch 00064: val_loss did not improve from 0.59914
# Epoch 65/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6204 - acc: 0.5907 - val_loss: 0.6031 - val_acc: 0.6393
#
# Epoch 00065: val_loss did not improve from 0.59914
# Epoch 66/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6189 - acc: 0.5947 - val_loss: 0.6132 - val_acc: 0.6120
#
# Epoch 00066: val_loss did not improve from 0.59914
# Epoch 67/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6246 - acc: 0.5961 - val_loss: 0.6086 - val_acc: 0.6172
#
# Epoch 00067: val_loss did not improve from 0.59914
# Epoch 68/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6149 - acc: 0.5946 - val_loss: 0.5978 - val_acc: 0.6354
#
# Epoch 00068: val_loss improved from 0.59914 to 0.59776, saving model to checkpoint.h5
# Epoch 69/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6366 - acc: 0.5851 - val_loss: 0.6039 - val_acc: 0.6471
#
# Epoch 00069: val_loss did not improve from 0.59776
# Epoch 70/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6205 - acc: 0.6127 - val_loss: 0.6069 - val_acc: 0.6094
#
# Epoch 00070: val_loss did not improve from 0.59776
# Epoch 71/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6272 - acc: 0.5943 - val_loss: 0.6024 - val_acc: 0.6341
#
# Epoch 00071: val_loss did not improve from 0.59776
# Epoch 72/150
# 14/14 [==============================] - 6s 428ms/step - loss: 0.6236 - acc: 0.6056 - val_loss: 0.6053 - val_acc: 0.6315
#
# Epoch 00072: val_loss did not improve from 0.59776
# Epoch 73/150
# 14/14 [==============================] - 6s 428ms/step - loss: 0.6074 - acc: 0.6083 - val_loss: 0.6039 - val_acc: 0.6419
#
# Epoch 00073: val_loss did not improve from 0.59776
# Epoch 74/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6178 - acc: 0.6022 - val_loss: 0.6056 - val_acc: 0.6198
#
# Epoch 00074: val_loss did not improve from 0.59776
# Epoch 75/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6313 - acc: 0.5738 - val_loss: 0.6060 - val_acc: 0.6081
#
# Epoch 00075: val_loss did not improve from 0.59776
# Epoch 76/150
# 14/14 [==============================] - 6s 432ms/step - loss: 0.6097 - acc: 0.6166 - val_loss: 0.6127 - val_acc: 0.6068
#
# Epoch 00076: val_loss did not improve from 0.59776
# Epoch 77/150
# 14/14 [==============================] - 6s 434ms/step - loss: 0.6237 - acc: 0.5928 - val_loss: 0.6021 - val_acc: 0.6380
#
# Epoch 00077: val_loss did not improve from 0.59776
# Epoch 78/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6186 - acc: 0.6019 - val_loss: 0.5959 - val_acc: 0.6523
#
# Epoch 00078: val_loss improved from 0.59776 to 0.59589, saving model to checkpoint.h5
# Epoch 79/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6237 - acc: 0.6130 - val_loss: 0.6068 - val_acc: 0.6432
#
# Epoch 00079: val_loss did not improve from 0.59589
# Epoch 80/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6202 - acc: 0.5953 - val_loss: 0.6672 - val_acc: 0.5534
#
# Epoch 00080: val_loss did not improve from 0.59589
# Epoch 81/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6253 - acc: 0.5901 - val_loss: 0.6045 - val_acc: 0.6094
#
# Epoch 00081: val_loss did not improve from 0.59589
# Epoch 82/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6229 - acc: 0.6105 - val_loss: 0.6053 - val_acc: 0.6276
#
# Epoch 00082: val_loss did not improve from 0.59589
# Epoch 83/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6095 - acc: 0.6009 - val_loss: 0.5993 - val_acc: 0.6432
#
# Epoch 00083: val_loss did not improve from 0.59589
# Epoch 84/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6113 - acc: 0.6255 - val_loss: 0.6097 - val_acc: 0.6289
#
# Epoch 00084: val_loss did not improve from 0.59589
# Epoch 85/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6259 - acc: 0.5915 - val_loss: 0.6080 - val_acc: 0.6237
#
# Epoch 00085: val_loss did not improve from 0.59589
# Epoch 86/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6112 - acc: 0.6213 - val_loss: 0.6027 - val_acc: 0.6484
#
# Epoch 00086: val_loss did not improve from 0.59589
# Epoch 87/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6198 - acc: 0.6088 - val_loss: 0.6056 - val_acc: 0.6211
#
# Epoch 00087: val_loss did not improve from 0.59589
# Epoch 88/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6197 - acc: 0.6010 - val_loss: 0.6054 - val_acc: 0.6302
#
# Epoch 00088: val_loss did not improve from 0.59589
# Epoch 89/150
# 14/14 [==============================] - 6s 416ms/step - loss: 0.6062 - acc: 0.6288 - val_loss: 0.6003 - val_acc: 0.6406
#
# Epoch 00089: val_loss did not improve from 0.59589
# Epoch 90/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6171 - acc: 0.6246 - val_loss: 0.6013 - val_acc: 0.6211
#
# Epoch 00090: val_loss did not improve from 0.59589
# Epoch 91/150
# 14/14 [==============================] - 6s 430ms/step - loss: 0.6076 - acc: 0.6115 - val_loss: 0.6117 - val_acc: 0.6198
#
# Epoch 00091: val_loss did not improve from 0.59589
# Epoch 92/150
# 14/14 [==============================] - 6s 434ms/step - loss: 0.6068 - acc: 0.6152 - val_loss: 0.6067 - val_acc: 0.6185
#
# Epoch 00092: val_loss did not improve from 0.59589
# Epoch 93/150
# 14/14 [==============================] - 6s 431ms/step - loss: 0.6149 - acc: 0.5883 - val_loss: 0.5964 - val_acc: 0.6367
#
# Epoch 00093: val_loss did not improve from 0.59589
# Epoch 94/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6069 - acc: 0.6255 - val_loss: 0.6145 - val_acc: 0.6198
#
# Epoch 00094: val_loss did not improve from 0.59589
# Epoch 95/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6235 - acc: 0.5873 - val_loss: 0.6048 - val_acc: 0.6549
#
# Epoch 00095: val_loss did not improve from 0.59589
# Epoch 96/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6127 - acc: 0.6199 - val_loss: 0.5974 - val_acc: 0.6510
#
# Epoch 00096: val_loss did not improve from 0.59589
# Epoch 97/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6254 - acc: 0.6370 - val_loss: 0.6164 - val_acc: 0.6354
#
# Epoch 00097: val_loss did not improve from 0.59589
# Epoch 98/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6269 - acc: 0.5863 - val_loss: 0.6102 - val_acc: 0.6172
#
# Epoch 00098: val_loss did not improve from 0.59589
# Epoch 99/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6014 - acc: 0.6228 - val_loss: 0.6004 - val_acc: 0.6393
#
# Epoch 00099: val_loss did not improve from 0.59589
# Epoch 100/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6099 - acc: 0.5937 - val_loss: 0.5970 - val_acc: 0.6380
#
# Epoch 00100: val_loss did not improve from 0.59589
# Epoch 101/150
# 14/14 [==============================] - 6s 432ms/step - loss: 0.6058 - acc: 0.6396 - val_loss: 0.6312 - val_acc: 0.6068
#
# Epoch 00101: val_loss did not improve from 0.59589
# Epoch 102/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6150 - acc: 0.6117 - val_loss: 0.6056 - val_acc: 0.6237
#
# Epoch 00102: val_loss did not improve from 0.59589
# Epoch 103/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6293 - acc: 0.5795 - val_loss: 0.6016 - val_acc: 0.6315
#
# Epoch 00103: val_loss did not improve from 0.59589
# Epoch 104/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.6079 - acc: 0.6244 - val_loss: 0.6120 - val_acc: 0.6120
#
# Epoch 00104: val_loss did not improve from 0.59589
# Epoch 105/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6215 - acc: 0.5928 - val_loss: 0.5968 - val_acc: 0.6562
#
# Epoch 00105: val_loss did not improve from 0.59589
# Epoch 106/150
# 14/14 [==============================] - 6s 429ms/step - loss: 0.6139 - acc: 0.6151 - val_loss: 0.6063 - val_acc: 0.6211
#
# Epoch 00106: val_loss did not improve from 0.59589
# Epoch 107/150
# 14/14 [==============================] - 6s 437ms/step - loss: 0.6095 - acc: 0.6203 - val_loss: 0.5967 - val_acc: 0.6419
#
# Epoch 00107: val_loss did not improve from 0.59589
# Epoch 108/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6161 - acc: 0.6244 - val_loss: 0.5992 - val_acc: 0.6406
#
# Epoch 00108: val_loss did not improve from 0.59589
# Epoch 109/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6215 - acc: 0.6232 - val_loss: 0.5960 - val_acc: 0.6458
#
# Epoch 00109: val_loss did not improve from 0.59589
# Epoch 110/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6046 - acc: 0.6303 - val_loss: 0.6073 - val_acc: 0.6315
#
# Epoch 00110: val_loss did not improve from 0.59589
# Epoch 111/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6030 - acc: 0.6144 - val_loss: 0.6068 - val_acc: 0.6328
#
# Epoch 00111: val_loss did not improve from 0.59589
# Epoch 112/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6080 - acc: 0.5990 - val_loss: 0.6085 - val_acc: 0.6315
#
# Epoch 00112: val_loss did not improve from 0.59589
# Epoch 113/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6101 - acc: 0.6183 - val_loss: 0.6115 - val_acc: 0.6133
#
# Epoch 00113: val_loss did not improve from 0.59589
# Epoch 114/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6289 - acc: 0.5986 - val_loss: 0.6031 - val_acc: 0.6445
#
# Epoch 00114: val_loss did not improve from 0.59589
# Epoch 115/150
# 14/14 [==============================] - 6s 429ms/step - loss: 0.6011 - acc: 0.6213 - val_loss: 0.5970 - val_acc: 0.6628
#
# Epoch 00115: val_loss did not improve from 0.59589
# Epoch 116/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6220 - acc: 0.6350 - val_loss: 0.6024 - val_acc: 0.6367
#
# Epoch 00116: val_loss did not improve from 0.59589
# Epoch 117/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.5936 - acc: 0.6234 - val_loss: 0.5985 - val_acc: 0.6224
#
# Epoch 00117: val_loss did not improve from 0.59589
# Epoch 118/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6072 - acc: 0.6092 - val_loss: 0.5995 - val_acc: 0.6302
#
# Epoch 00118: val_loss did not improve from 0.59589
# Epoch 119/150
# 14/14 [==============================] - 6s 426ms/step - loss: 0.5998 - acc: 0.6200 - val_loss: 0.6129 - val_acc: 0.6224
#
# Epoch 00119: val_loss did not improve from 0.59589
# Epoch 120/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6049 - acc: 0.6027 - val_loss: 0.5904 - val_acc: 0.6589
#
# Epoch 00120: val_loss improved from 0.59589 to 0.59042, saving model to checkpoint.h5
# Epoch 121/150
# 14/14 [==============================] - 6s 434ms/step - loss: 0.6104 - acc: 0.6222 - val_loss: 0.5961 - val_acc: 0.6367
#
# Epoch 00121: val_loss did not improve from 0.59042
# Epoch 122/150
# 14/14 [==============================] - 6s 435ms/step - loss: 0.6004 - acc: 0.6272 - val_loss: 0.6080 - val_acc: 0.6341
#
# Epoch 00122: val_loss did not improve from 0.59042
# Epoch 123/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.5998 - acc: 0.6140 - val_loss: 0.6182 - val_acc: 0.6133
#
# Epoch 00123: val_loss did not improve from 0.59042
# Epoch 124/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6157 - acc: 0.6285 - val_loss: 0.5990 - val_acc: 0.6497
#
# Epoch 00124: val_loss did not improve from 0.59042
# Epoch 125/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6089 - acc: 0.6235 - val_loss: 0.6029 - val_acc: 0.6419
#
# Epoch 00125: val_loss did not improve from 0.59042
# Epoch 126/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.6044 - acc: 0.6305 - val_loss: 0.6019 - val_acc: 0.6549
#
# Epoch 00126: val_loss did not improve from 0.59042
# Epoch 127/150
# 14/14 [==============================] - 6s 425ms/step - loss: 0.5965 - acc: 0.6416 - val_loss: 0.6084 - val_acc: 0.6289
#
# Epoch 00127: val_loss did not improve from 0.59042
# Epoch 128/150
# 14/14 [==============================] - 6s 427ms/step - loss: 0.5844 - acc: 0.6309 - val_loss: 0.6096 - val_acc: 0.6237
#
# Epoch 00128: val_loss did not improve from 0.59042
# Epoch 129/150
# 14/14 [==============================] - 6s 428ms/step - loss: 0.5937 - acc: 0.6371 - val_loss: 0.6108 - val_acc: 0.6250
#
# Epoch 00129: val_loss did not improve from 0.59042
# Epoch 130/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.6069 - acc: 0.6114 - val_loss: 0.5887 - val_acc: 0.6602
#
# Epoch 00130: val_loss improved from 0.59042 to 0.58870, saving model to checkpoint.h5
# Epoch 131/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6007 - acc: 0.6289 - val_loss: 0.5972 - val_acc: 0.6549
#
# Epoch 00131: val_loss did not improve from 0.58870
# Epoch 132/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6094 - acc: 0.6353 - val_loss: 0.5925 - val_acc: 0.6523
#
# Epoch 00132: val_loss did not improve from 0.58870
# Epoch 133/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.6152 - acc: 0.6157 - val_loss: 0.5928 - val_acc: 0.6497
#
# Epoch 00133: val_loss did not improve from 0.58870
# Epoch 134/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.5992 - acc: 0.6287 - val_loss: 0.6130 - val_acc: 0.6211
#
# Epoch 00134: val_loss did not improve from 0.58870
# Epoch 135/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.5900 - acc: 0.6326 - val_loss: 0.5925 - val_acc: 0.6510
#
# Epoch 00135: val_loss did not improve from 0.58870
# Epoch 136/150
# 14/14 [==============================] - 6s 434ms/step - loss: 0.6047 - acc: 0.6164 - val_loss: 0.5944 - val_acc: 0.6654
#
# Epoch 00136: val_loss did not improve from 0.58870
# Epoch 137/150
# 14/14 [==============================] - 6s 439ms/step - loss: 0.6027 - acc: 0.6441 - val_loss: 0.5990 - val_acc: 0.6510
#
# Epoch 00137: val_loss did not improve from 0.58870
# Epoch 138/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.5936 - acc: 0.6030 - val_loss: 0.5979 - val_acc: 0.6432
#
# Epoch 00138: val_loss did not improve from 0.58870
# Epoch 139/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.6181 - acc: 0.6162 - val_loss: 0.5943 - val_acc: 0.6484
#
# Epoch 00139: val_loss did not improve from 0.58870
# Epoch 140/150
# 14/14 [==============================] - 6s 428ms/step - loss: 0.5876 - acc: 0.6335 - val_loss: 0.6096 - val_acc: 0.6354
#
# Epoch 00140: val_loss did not improve from 0.58870
# Epoch 141/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6018 - acc: 0.6215 - val_loss: 0.5906 - val_acc: 0.6628
#
# Epoch 00141: val_loss did not improve from 0.58870
# Epoch 142/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.5821 - acc: 0.6431 - val_loss: 0.5942 - val_acc: 0.6680
#
# Epoch 00142: val_loss did not improve from 0.58870
# Epoch 143/150
# 14/14 [==============================] - 6s 430ms/step - loss: 0.5907 - acc: 0.6492 - val_loss: 0.6093 - val_acc: 0.6354
#
# Epoch 00143: val_loss did not improve from 0.58870
# Epoch 144/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.6084 - acc: 0.6109 - val_loss: 0.5994 - val_acc: 0.6393
#
# Epoch 00144: val_loss did not improve from 0.58870
# Epoch 145/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6019 - acc: 0.6109 - val_loss: 0.6100 - val_acc: 0.6185
#
# Epoch 00145: val_loss did not improve from 0.58870
# Epoch 146/150
# 14/14 [==============================] - 6s 424ms/step - loss: 0.5952 - acc: 0.6261 - val_loss: 0.5970 - val_acc: 0.6497
#
# Epoch 00146: val_loss did not improve from 0.58870
# Epoch 147/150
# 14/14 [==============================] - 6s 437ms/step - loss: 0.5830 - acc: 0.6375 - val_loss: 0.5980 - val_acc: 0.6523
#
# Epoch 00147: val_loss did not improve from 0.58870
# Epoch 148/150
# 14/14 [==============================] - 6s 430ms/step - loss: 0.5748 - acc: 0.6464 - val_loss: 0.5901 - val_acc: 0.6445
#
# Epoch 00148: val_loss did not improve from 0.58870
# Epoch 149/150
# 14/14 [==============================] - 6s 427ms/step - loss: 0.5945 - acc: 0.6310 - val_loss: 0.5931 - val_acc: 0.6510
#
# Epoch 00149: val_loss did not improve from 0.58870
# Epoch 150/150
# 14/14 [==============================] - 6s 420ms/step - loss: 0.6100 - acc: 0.6178 - val_loss: 0.5903 - val_acc: 0.6654
#
# Epoch 00150: val_loss did not improve from 0.58870
# Specificity :  0.4611872146118721
# Sensitivity :  0.7094017094017094
#               precision    recall  f1-score   support
#
#            0     0.7481    0.4612    0.5706       219
#            1     0.4129    0.7094    0.5220       117
#
#     accuracy                         0.5476       336
#    macro avg     0.5805    0.5853    0.5463       336
# weighted avg     0.6314    0.5476    0.5537       336
# Result: f2_score=0.620

# %% [markdown]
# ### CNN 2D

# %% [markdown]
# #### Preprocessing
# We perform Data Augmentation with the training set in order to increase the number of data.
#
# We consider geometric transformations, such as the rotation, the vertical and horizontal flip. We choose as fill mode the default value which fills the area with the nearest pixel and stretching it.
#
# The rescaling is made to 65535 because the dataset is composed by 16 bit images.

# %%
def get_data_gen(data, labels, data_gen_args = {}, seed = 1):
  datagen_abnormality = ImageDataGenerator(**data_gen_args)
  # Provide the same seed and keyword arguments to the fit and flow methods
  datagen_abnormality.fit(data[:,0,:,:,:], seed=seed)


  generator_abnormality = datagen_abnormality.flow(data[:,0,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)
  generator_base = datagen_abnormality.flow(data[:,1,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)

  # combine generators into one which yields image and masks
  while True:
    abnormality_image, label = generator_abnormality.next()
    base_image, _ = generator_base.next()
    yield np.stack((abnormality_image[:,:,:,0], base_image[:,:,:,0]), axis=-1), label

# %%
train_datagen_args = dict(
    rotation_range=180,
    vertical_flip = True,
    horizontal_flip = True)

train_generator = get_data_gen(train_images, train_labels, train_datagen_args)

validation_generator = get_data_gen(valid_images, valid_labels)

# %% [markdown]
# #### Experiment 1

# %%
input_shape = (150, 150, 2)

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy',
              # optimizer=keras.optimizers.RMSprop(lr=2e-5),
              optimizer=keras.optimizers.Adam(learning_rate=0.0001),
              metrics=['acc'])

model_checkpoint = ModelCheckpoint('checkpoint.h5', save_best_only=True, save_weights_only=True, verbose=1)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_acc', patience=50)

history = model.fit(
  train_generator,
  steps_per_epoch = len(train_images) // BATCH_SIZE,
  epochs=150,
  class_weight = class_weights,
  validation_data = validation_generator,
  validation_steps =  len(valid_images) // BATCH_SIZE,
  callbacks = [callback, model_checkpoint]
  )
model.load_weights('checkpoint.h5')
performance_plot(history, model, np.stack((test_images[:,0,:,:,0], test_images[:,1,:,:,0]), axis=-1), test_labels)
models.save_model(model, os.path.join(MODEL_PATH, 'model_2d.h5'))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 32)      608
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               802944
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 941,153
# Trainable params: 941,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6941 - acc: 0.4787 - val_loss: 0.6986 - val_acc: 0.4141
#
# Epoch 00001: val_loss improved from inf to 0.69861, saving model to checkpoint.h5
# Epoch 2/150
# 14/14 [==============================] - 6s 462ms/step - loss: 0.6924 - acc: 0.4299 - val_loss: 0.6931 - val_acc: 0.4570
#
# Epoch 00002: val_loss improved from 0.69861 to 0.69310, saving model to checkpoint.h5
# Epoch 3/150
# 14/14 [==============================] - 6s 470ms/step - loss: 0.6835 - acc: 0.5097 - val_loss: 0.7038 - val_acc: 0.4375
#
# Epoch 00003: val_loss did not improve from 0.69310
# Epoch 4/150
# 14/14 [==============================] - 7s 490ms/step - loss: 0.6900 - acc: 0.4915 - val_loss: 0.6876 - val_acc: 0.5208
#
# Epoch 00004: val_loss improved from 0.69310 to 0.68760, saving model to checkpoint.h5
# Epoch 5/150
# 14/14 [==============================] - 7s 501ms/step - loss: 0.6824 - acc: 0.5557 - val_loss: 0.6701 - val_acc: 0.6302
#
# Epoch 00005: val_loss improved from 0.68760 to 0.67014, saving model to checkpoint.h5
# Epoch 6/150
# 14/14 [==============================] - 6s 412ms/step - loss: 0.6798 - acc: 0.5843 - val_loss: 0.6678 - val_acc: 0.6406
#
# Epoch 00006: val_loss improved from 0.67014 to 0.66781, saving model to checkpoint.h5
# Epoch 7/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6875 - acc: 0.5917 - val_loss: 0.6983 - val_acc: 0.4531
#
# Epoch 00007: val_loss did not improve from 0.66781
# Epoch 8/150
# 14/14 [==============================] - 5s 409ms/step - loss: 0.6826 - acc: 0.5311 - val_loss: 0.6761 - val_acc: 0.5924
#
# Epoch 00008: val_loss did not improve from 0.66781
# Epoch 9/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6779 - acc: 0.5584 - val_loss: 0.6616 - val_acc: 0.6367
#
# Epoch 00009: val_loss improved from 0.66781 to 0.66164, saving model to checkpoint.h5
# Epoch 10/150
# 14/14 [==============================] - 6s 410ms/step - loss: 0.6745 - acc: 0.5636 - val_loss: 0.6656 - val_acc: 0.6094
#
# Epoch 00010: val_loss did not improve from 0.66164
# Epoch 11/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6740 - acc: 0.6118 - val_loss: 0.6630 - val_acc: 0.6029
#
# Epoch 00011: val_loss did not improve from 0.66164
# Epoch 12/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6680 - acc: 0.5895 - val_loss: 0.6586 - val_acc: 0.6198
#
# Epoch 00012: val_loss improved from 0.66164 to 0.65856, saving model to checkpoint.h5
# Epoch 13/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6597 - acc: 0.6113 - val_loss: 0.6779 - val_acc: 0.5651
#
# Epoch 00013: val_loss did not improve from 0.65856
# Epoch 14/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.6631 - acc: 0.6058 - val_loss: 0.6391 - val_acc: 0.6380
#
# Epoch 00014: val_loss improved from 0.65856 to 0.63910, saving model to checkpoint.h5
# Epoch 15/150
# 14/14 [==============================] - 5s 401ms/step - loss: 0.6535 - acc: 0.6076 - val_loss: 0.6418 - val_acc: 0.6458
#
# Epoch 00015: val_loss did not improve from 0.63910
# Epoch 16/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.6580 - acc: 0.6035 - val_loss: 0.6437 - val_acc: 0.6211
#
# Epoch 00016: val_loss did not improve from 0.63910
# Epoch 17/150
# 14/14 [==============================] - 5s 417ms/step - loss: 0.6617 - acc: 0.5882 - val_loss: 0.6388 - val_acc: 0.6367
#
# Epoch 00017: val_loss improved from 0.63910 to 0.63876, saving model to checkpoint.h5
# Epoch 18/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6482 - acc: 0.6207 - val_loss: 0.6269 - val_acc: 0.6406
#
# Epoch 00018: val_loss improved from 0.63876 to 0.62691, saving model to checkpoint.h5
# Epoch 19/150
# 14/14 [==============================] - 5s 409ms/step - loss: 0.6554 - acc: 0.6085 - val_loss: 0.6443 - val_acc: 0.6224
#
# Epoch 00019: val_loss did not improve from 0.62691
# Epoch 20/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6594 - acc: 0.5713 - val_loss: 0.6439 - val_acc: 0.6315
#
# Epoch 00020: val_loss did not improve from 0.62691
# Epoch 21/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6406 - acc: 0.6045 - val_loss: 0.6531 - val_acc: 0.6120
#
# Epoch 00021: val_loss did not improve from 0.62691
# Epoch 22/150
# 14/14 [==============================] - 5s 399ms/step - loss: 0.6478 - acc: 0.6182 - val_loss: 0.6224 - val_acc: 0.6445
#
# Epoch 00022: val_loss improved from 0.62691 to 0.62239, saving model to checkpoint.h5
# Epoch 23/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.6412 - acc: 0.6168 - val_loss: 0.6181 - val_acc: 0.6432
#
# Epoch 00023: val_loss improved from 0.62239 to 0.61810, saving model to checkpoint.h5
# Epoch 24/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6436 - acc: 0.6292 - val_loss: 0.6153 - val_acc: 0.6341
#
# Epoch 00024: val_loss improved from 0.61810 to 0.61531, saving model to checkpoint.h5
# Epoch 25/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6378 - acc: 0.6074 - val_loss: 0.6135 - val_acc: 0.6497
#
# Epoch 00025: val_loss improved from 0.61531 to 0.61347, saving model to checkpoint.h5
# Epoch 26/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6536 - acc: 0.5969 - val_loss: 0.6197 - val_acc: 0.6432
#
# Epoch 00026: val_loss did not improve from 0.61347
# Epoch 27/150
# 14/14 [==============================] - 6s 412ms/step - loss: 0.6383 - acc: 0.6186 - val_loss: 0.6263 - val_acc: 0.6315
#
# Epoch 00027: val_loss did not improve from 0.61347
# Epoch 28/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6406 - acc: 0.6116 - val_loss: 0.6099 - val_acc: 0.6380
#
# Epoch 00028: val_loss improved from 0.61347 to 0.60993, saving model to checkpoint.h5
# Epoch 29/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6477 - acc: 0.6063 - val_loss: 0.6111 - val_acc: 0.6549
#
# Epoch 00029: val_loss did not improve from 0.60993
# Epoch 30/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6455 - acc: 0.6034 - val_loss: 0.6330 - val_acc: 0.6250
#
# Epoch 00030: val_loss did not improve from 0.60993
# Epoch 31/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6413 - acc: 0.5943 - val_loss: 0.6196 - val_acc: 0.6380
#
# Epoch 00031: val_loss did not improve from 0.60993
# Epoch 32/150
# 14/14 [==============================] - 5s 413ms/step - loss: 0.6308 - acc: 0.5917 - val_loss: 0.6159 - val_acc: 0.6380
#
# Epoch 00032: val_loss did not improve from 0.60993
# Epoch 33/150
# 14/14 [==============================] - 5s 399ms/step - loss: 0.6338 - acc: 0.6260 - val_loss: 0.6362 - val_acc: 0.6146
#
# Epoch 00033: val_loss did not improve from 0.60993
# Epoch 34/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6313 - acc: 0.6133 - val_loss: 0.6386 - val_acc: 0.6094
#
# Epoch 00034: val_loss did not improve from 0.60993
# Epoch 35/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.6284 - acc: 0.6195 - val_loss: 0.6254 - val_acc: 0.6211
#
# Epoch 00035: val_loss did not improve from 0.60993
# Epoch 36/150
# 14/14 [==============================] - 6s 409ms/step - loss: 0.6298 - acc: 0.5903 - val_loss: 0.6115 - val_acc: 0.6328
#
# Epoch 00036: val_loss did not improve from 0.60993
# Epoch 37/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6371 - acc: 0.5946 - val_loss: 0.6070 - val_acc: 0.6458
#
# Epoch 00037: val_loss improved from 0.60993 to 0.60702, saving model to checkpoint.h5
# Epoch 38/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6220 - acc: 0.6178 - val_loss: 0.6138 - val_acc: 0.6328
#
# Epoch 00038: val_loss did not improve from 0.60702
# Epoch 39/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6207 - acc: 0.6130 - val_loss: 0.6086 - val_acc: 0.6380
#
# Epoch 00039: val_loss did not improve from 0.60702
# Epoch 40/150
# 14/14 [==============================] - 5s 401ms/step - loss: 0.6161 - acc: 0.6105 - val_loss: 0.6020 - val_acc: 0.6393
#
# Epoch 00040: val_loss improved from 0.60702 to 0.60196, saving model to checkpoint.h5
# Epoch 41/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6326 - acc: 0.6046 - val_loss: 0.6051 - val_acc: 0.6445
#
# Epoch 00041: val_loss did not improve from 0.60196
# Epoch 42/150
# 14/14 [==============================] - 5s 400ms/step - loss: 0.6196 - acc: 0.6407 - val_loss: 0.6012 - val_acc: 0.6523
#
# Epoch 00042: val_loss improved from 0.60196 to 0.60121, saving model to checkpoint.h5
# Epoch 43/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6254 - acc: 0.6118 - val_loss: 0.6096 - val_acc: 0.6419
#
# Epoch 00043: val_loss did not improve from 0.60121
# Epoch 44/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6226 - acc: 0.6099 - val_loss: 0.6042 - val_acc: 0.6393
#
# Epoch 00044: val_loss did not improve from 0.60121
# Epoch 45/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6204 - acc: 0.6227 - val_loss: 0.6108 - val_acc: 0.6393
#
# Epoch 00045: val_loss did not improve from 0.60121
# Epoch 46/150
# 14/14 [==============================] - 6s 414ms/step - loss: 0.6003 - acc: 0.6374 - val_loss: 0.6012 - val_acc: 0.6432
#
# Epoch 00046: val_loss improved from 0.60121 to 0.60116, saving model to checkpoint.h5
# Epoch 47/150
# 14/14 [==============================] - 5s 410ms/step - loss: 0.6344 - acc: 0.6032 - val_loss: 0.5974 - val_acc: 0.6523
#
# Epoch 00047: val_loss improved from 0.60116 to 0.59740, saving model to checkpoint.h5
# Epoch 48/150
# 14/14 [==============================] - 5s 399ms/step - loss: 0.5911 - acc: 0.6495 - val_loss: 0.6088 - val_acc: 0.6328
#
# Epoch 00048: val_loss did not improve from 0.59740
# Epoch 49/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6214 - acc: 0.5869 - val_loss: 0.5943 - val_acc: 0.6693
#
# Epoch 00049: val_loss improved from 0.59740 to 0.59427, saving model to checkpoint.h5
# Epoch 50/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.6177 - acc: 0.6316 - val_loss: 0.5989 - val_acc: 0.6484
#
# Epoch 00050: val_loss did not improve from 0.59427
# Epoch 51/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6125 - acc: 0.6256 - val_loss: 0.6007 - val_acc: 0.6380
#
# Epoch 00051: val_loss did not improve from 0.59427
# Epoch 52/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6080 - acc: 0.6289 - val_loss: 0.5946 - val_acc: 0.6549
#
# Epoch 00052: val_loss did not improve from 0.59427
# Epoch 53/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6189 - acc: 0.6158 - val_loss: 0.6250 - val_acc: 0.6250
#
# Epoch 00053: val_loss did not improve from 0.59427
# Epoch 54/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6151 - acc: 0.6018 - val_loss: 0.6232 - val_acc: 0.6159
#
# Epoch 00054: val_loss did not improve from 0.59427
# Epoch 55/150
# 14/14 [==============================] - 5s 401ms/step - loss: 0.6210 - acc: 0.6184 - val_loss: 0.6307 - val_acc: 0.6380
#
# Epoch 00055: val_loss did not improve from 0.59427
# Epoch 56/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6166 - acc: 0.6165 - val_loss: 0.6487 - val_acc: 0.5924
#
# Epoch 00056: val_loss did not improve from 0.59427
# Epoch 57/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6292 - acc: 0.5681 - val_loss: 0.6079 - val_acc: 0.6354
#
# Epoch 00057: val_loss did not improve from 0.59427
# Epoch 58/150
# 14/14 [==============================] - 5s 400ms/step - loss: 0.6072 - acc: 0.6208 - val_loss: 0.5937 - val_acc: 0.6576
#
# Epoch 00058: val_loss improved from 0.59427 to 0.59374, saving model to checkpoint.h5
# Epoch 59/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6133 - acc: 0.6408 - val_loss: 0.6108 - val_acc: 0.6237
#
# Epoch 00059: val_loss did not improve from 0.59374
# Epoch 60/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6060 - acc: 0.5991 - val_loss: 0.6048 - val_acc: 0.6198
#
# Epoch 00060: val_loss did not improve from 0.59374
# Epoch 61/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.6341 - acc: 0.5759 - val_loss: 0.5975 - val_acc: 0.6536
#
# Epoch 00061: val_loss did not improve from 0.59374
# Epoch 62/150
# 14/14 [==============================] - 5s 414ms/step - loss: 0.6114 - acc: 0.6203 - val_loss: 0.6054 - val_acc: 0.6328
#
# Epoch 00062: val_loss did not improve from 0.59374
# Epoch 63/150
# 14/14 [==============================] - 5s 408ms/step - loss: 0.6087 - acc: 0.6175 - val_loss: 0.5987 - val_acc: 0.6380
#
# Epoch 00063: val_loss did not improve from 0.59374
# Epoch 64/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6017 - acc: 0.6392 - val_loss: 0.6055 - val_acc: 0.6289
#
# Epoch 00064: val_loss did not improve from 0.59374
# Epoch 65/150
# 14/14 [==============================] - 5s 399ms/step - loss: 0.6203 - acc: 0.6079 - val_loss: 0.6019 - val_acc: 0.6276
#
# Epoch 00065: val_loss did not improve from 0.59374
# Epoch 66/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6057 - acc: 0.6218 - val_loss: 0.6212 - val_acc: 0.6315
#
# Epoch 00066: val_loss did not improve from 0.59374
# Epoch 67/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6142 - acc: 0.6213 - val_loss: 0.6244 - val_acc: 0.6055
#
# Epoch 00067: val_loss did not improve from 0.59374
# Epoch 68/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6159 - acc: 0.6009 - val_loss: 0.5977 - val_acc: 0.6523
#
# Epoch 00068: val_loss did not improve from 0.59374
# Epoch 69/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.6268 - acc: 0.6179 - val_loss: 0.5976 - val_acc: 0.6536
#
# Epoch 00069: val_loss did not improve from 0.59374
# Epoch 70/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5963 - acc: 0.6391 - val_loss: 0.5990 - val_acc: 0.6432
#
# Epoch 00070: val_loss did not improve from 0.59374
# Epoch 71/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6232 - acc: 0.6098 - val_loss: 0.5948 - val_acc: 0.6393
#
# Epoch 00071: val_loss did not improve from 0.59374
# Epoch 72/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6027 - acc: 0.6159 - val_loss: 0.5919 - val_acc: 0.6536
#
# Epoch 00072: val_loss improved from 0.59374 to 0.59195, saving model to checkpoint.h5
# Epoch 73/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5886 - acc: 0.6471 - val_loss: 0.5987 - val_acc: 0.6576
#
# Epoch 00073: val_loss did not improve from 0.59195
# Epoch 74/150
# 14/14 [==============================] - 5s 408ms/step - loss: 0.6046 - acc: 0.6451 - val_loss: 0.6044 - val_acc: 0.6380
#
# Epoch 00074: val_loss did not improve from 0.59195
# Epoch 75/150
# 14/14 [==============================] - 6s 413ms/step - loss: 0.6169 - acc: 0.5926 - val_loss: 0.5999 - val_acc: 0.6523
#
# Epoch 00075: val_loss did not improve from 0.59195
# Epoch 76/150
# 14/14 [==============================] - 6s 416ms/step - loss: 0.5981 - acc: 0.6176 - val_loss: 0.5999 - val_acc: 0.6367
#
# Epoch 00076: val_loss did not improve from 0.59195
# Epoch 77/150
# 14/14 [==============================] - 5s 417ms/step - loss: 0.6092 - acc: 0.6206 - val_loss: 0.5938 - val_acc: 0.6536
#
# Epoch 00077: val_loss did not improve from 0.59195
# Epoch 78/150
# 14/14 [==============================] - 6s 413ms/step - loss: 0.6150 - acc: 0.6100 - val_loss: 0.5918 - val_acc: 0.6628
#
# Epoch 00078: val_loss improved from 0.59195 to 0.59182, saving model to checkpoint.h5
# Epoch 79/150
# 14/14 [==============================] - 5s 409ms/step - loss: 0.6084 - acc: 0.6495 - val_loss: 0.6026 - val_acc: 0.6341
#
# Epoch 00079: val_loss did not improve from 0.59182
# Epoch 80/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5914 - acc: 0.6331 - val_loss: 0.6028 - val_acc: 0.6380
#
# Epoch 00080: val_loss did not improve from 0.59182
# Epoch 81/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.6034 - acc: 0.6248 - val_loss: 0.5962 - val_acc: 0.6354
#
# Epoch 00081: val_loss did not improve from 0.59182
# Epoch 82/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6028 - acc: 0.6332 - val_loss: 0.6014 - val_acc: 0.6328
#
# Epoch 00082: val_loss did not improve from 0.59182
# Epoch 83/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.5882 - acc: 0.6453 - val_loss: 0.5930 - val_acc: 0.6654
#
# Epoch 00083: val_loss did not improve from 0.59182
# Epoch 84/150
# 14/14 [==============================] - 6s 415ms/step - loss: 0.5893 - acc: 0.6285 - val_loss: 0.6042 - val_acc: 0.6341
#
# Epoch 00084: val_loss did not improve from 0.59182
# Epoch 85/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6112 - acc: 0.6240 - val_loss: 0.5987 - val_acc: 0.6380
#
# Epoch 00085: val_loss did not improve from 0.59182
# Epoch 86/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.6006 - acc: 0.6217 - val_loss: 0.5952 - val_acc: 0.6549
#
# Epoch 00086: val_loss did not improve from 0.59182
# Epoch 87/150
# 14/14 [==============================] - 5s 403ms/step - loss: 0.5929 - acc: 0.6448 - val_loss: 0.5888 - val_acc: 0.6628
#
# Epoch 00087: val_loss improved from 0.59182 to 0.58879, saving model to checkpoint.h5
# Epoch 88/150
# 14/14 [==============================] - 5s 409ms/step - loss: 0.6006 - acc: 0.6407 - val_loss: 0.5920 - val_acc: 0.6654
#
# Epoch 00088: val_loss did not improve from 0.58879
# Epoch 89/150
# 14/14 [==============================] - 6s 410ms/step - loss: 0.6008 - acc: 0.6606 - val_loss: 0.5937 - val_acc: 0.6445
#
# Epoch 00089: val_loss did not improve from 0.58879
# Epoch 90/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5975 - acc: 0.6316 - val_loss: 0.5950 - val_acc: 0.6458
#
# Epoch 00090: val_loss did not improve from 0.58879
# Epoch 91/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.5826 - acc: 0.6605 - val_loss: 0.5887 - val_acc: 0.6458
#
# Epoch 00091: val_loss improved from 0.58879 to 0.58867, saving model to checkpoint.h5
# Epoch 92/150
# 14/14 [==============================] - 6s 419ms/step - loss: 0.5801 - acc: 0.6551 - val_loss: 0.6168 - val_acc: 0.6146
#
# Epoch 00092: val_loss did not improve from 0.58867
# Epoch 93/150
# 14/14 [==============================] - 6s 411ms/step - loss: 0.6113 - acc: 0.6211 - val_loss: 0.5906 - val_acc: 0.6615
#
# Epoch 00093: val_loss did not improve from 0.58867
# Epoch 94/150
# 14/14 [==============================] - 6s 409ms/step - loss: 0.5827 - acc: 0.6539 - val_loss: 0.5963 - val_acc: 0.6432
#
# Epoch 00094: val_loss did not improve from 0.58867
# Epoch 95/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6080 - acc: 0.6065 - val_loss: 0.5904 - val_acc: 0.6602
#
# Epoch 00095: val_loss did not improve from 0.58867
# Epoch 96/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5898 - acc: 0.6622 - val_loss: 0.5914 - val_acc: 0.6745
#
# Epoch 00096: val_loss did not improve from 0.58867
# Epoch 97/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6149 - acc: 0.6451 - val_loss: 0.5910 - val_acc: 0.6602
#
# Epoch 00097: val_loss did not improve from 0.58867
# Epoch 98/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6016 - acc: 0.6419 - val_loss: 0.5908 - val_acc: 0.6615
#
# Epoch 00098: val_loss did not improve from 0.58867
# Epoch 99/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5787 - acc: 0.6458 - val_loss: 0.6013 - val_acc: 0.6341
#
# Epoch 00099: val_loss did not improve from 0.58867
# Epoch 100/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.6036 - acc: 0.6392 - val_loss: 0.5939 - val_acc: 0.6471
#
# Epoch 00100: val_loss did not improve from 0.58867
# Epoch 101/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5843 - acc: 0.6484 - val_loss: 0.6066 - val_acc: 0.6315
#
# Epoch 00101: val_loss did not improve from 0.58867
# Epoch 102/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5959 - acc: 0.6395 - val_loss: 0.5978 - val_acc: 0.6393
#
# Epoch 00102: val_loss did not improve from 0.58867
# Epoch 103/150
# 14/14 [==============================] - 6s 409ms/step - loss: 0.6058 - acc: 0.6219 - val_loss: 0.5949 - val_acc: 0.6263
#
# Epoch 00103: val_loss did not improve from 0.58867
# Epoch 104/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5905 - acc: 0.6428 - val_loss: 0.6032 - val_acc: 0.6315
#
# Epoch 00104: val_loss did not improve from 0.58867
# Epoch 105/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.5995 - acc: 0.6489 - val_loss: 0.5905 - val_acc: 0.6510
#
# Epoch 00105: val_loss did not improve from 0.58867
# Epoch 106/150
# 14/14 [==============================] - 6s 421ms/step - loss: 0.5937 - acc: 0.6316 - val_loss: 0.5866 - val_acc: 0.6667
#
# Epoch 00106: val_loss improved from 0.58867 to 0.58661, saving model to checkpoint.h5
# Epoch 107/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.5923 - acc: 0.6477 - val_loss: 0.6024 - val_acc: 0.6237
#
# Epoch 00107: val_loss did not improve from 0.58661
# Epoch 108/150
# 14/14 [==============================] - 6s 412ms/step - loss: 0.5980 - acc: 0.6341 - val_loss: 0.5988 - val_acc: 0.6380
#
# Epoch 00108: val_loss did not improve from 0.58661
# Epoch 109/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.6025 - acc: 0.6294 - val_loss: 0.5888 - val_acc: 0.6693
#
# Epoch 00109: val_loss did not improve from 0.58661
# Epoch 110/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5823 - acc: 0.6494 - val_loss: 0.5885 - val_acc: 0.6771
#
# Epoch 00110: val_loss did not improve from 0.58661
# Epoch 111/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.5900 - acc: 0.6344 - val_loss: 0.5907 - val_acc: 0.6589
#
# Epoch 00111: val_loss did not improve from 0.58661
# Epoch 112/150
# 14/14 [==============================] - 5s 408ms/step - loss: 0.5889 - acc: 0.6442 - val_loss: 0.5853 - val_acc: 0.6654
#
# Epoch 00112: val_loss improved from 0.58661 to 0.58528, saving model to checkpoint.h5
# Epoch 113/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5788 - acc: 0.6723 - val_loss: 0.6070 - val_acc: 0.6276
#
# Epoch 00113: val_loss did not improve from 0.58528
# Epoch 114/150
# 14/14 [==============================] - 6s 408ms/step - loss: 0.6027 - acc: 0.6386 - val_loss: 0.5920 - val_acc: 0.6497
#
# Epoch 00114: val_loss did not improve from 0.58528
# Epoch 115/150
# 14/14 [==============================] - 5s 401ms/step - loss: 0.5862 - acc: 0.6382 - val_loss: 0.5937 - val_acc: 0.6758
#
# Epoch 00115: val_loss did not improve from 0.58528
# Epoch 116/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.5856 - acc: 0.6592 - val_loss: 0.6063 - val_acc: 0.6367
#
# Epoch 00116: val_loss did not improve from 0.58528
# Epoch 117/150
# 14/14 [==============================] - 5s 401ms/step - loss: 0.5701 - acc: 0.6500 - val_loss: 0.5993 - val_acc: 0.6237
#
# Epoch 00117: val_loss did not improve from 0.58528
# Epoch 118/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5841 - acc: 0.6475 - val_loss: 0.6087 - val_acc: 0.6198
#
# Epoch 00118: val_loss did not improve from 0.58528
# Epoch 119/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.5748 - acc: 0.6504 - val_loss: 0.6302 - val_acc: 0.5977
#
# Epoch 00119: val_loss did not improve from 0.58528
# Epoch 120/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.5857 - acc: 0.6342 - val_loss: 0.6360 - val_acc: 0.5938
#
# Epoch 00120: val_loss did not improve from 0.58528
# Epoch 121/150
# 14/14 [==============================] - 6s 417ms/step - loss: 0.6030 - acc: 0.6224 - val_loss: 0.6019 - val_acc: 0.6380
#
# Epoch 00121: val_loss did not improve from 0.58528
# Epoch 122/150
# 14/14 [==============================] - 6s 422ms/step - loss: 0.5762 - acc: 0.6581 - val_loss: 0.5970 - val_acc: 0.6484
#
# Epoch 00122: val_loss did not improve from 0.58528
# Epoch 123/150
# 14/14 [==============================] - 6s 412ms/step - loss: 0.5880 - acc: 0.6327 - val_loss: 0.6205 - val_acc: 0.5964
#
# Epoch 00123: val_loss did not improve from 0.58528
# Epoch 124/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5867 - acc: 0.6455 - val_loss: 0.5994 - val_acc: 0.6328
#
# Epoch 00124: val_loss did not improve from 0.58528
# Epoch 125/150
# 14/14 [==============================] - 6s 408ms/step - loss: 0.5878 - acc: 0.6376 - val_loss: 0.5923 - val_acc: 0.6667
#
# Epoch 00125: val_loss did not improve from 0.58528
# Epoch 126/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5949 - acc: 0.6509 - val_loss: 0.5903 - val_acc: 0.6693
#
# Epoch 00126: val_loss did not improve from 0.58528
# Epoch 127/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.5762 - acc: 0.6547 - val_loss: 0.6031 - val_acc: 0.6341
#
# Epoch 00127: val_loss did not improve from 0.58528
# Epoch 128/150
# 14/14 [==============================] - 5s 404ms/step - loss: 0.5819 - acc: 0.6558 - val_loss: 0.6262 - val_acc: 0.5964
#
# Epoch 00128: val_loss did not improve from 0.58528
# Epoch 129/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.5964 - acc: 0.6387 - val_loss: 0.5853 - val_acc: 0.6641
#
# Epoch 00129: val_loss improved from 0.58528 to 0.58526, saving model to checkpoint.h5
# Epoch 130/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5954 - acc: 0.6371 - val_loss: 0.5869 - val_acc: 0.6576
#
# Epoch 00130: val_loss did not improve from 0.58526
# Epoch 131/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5942 - acc: 0.6350 - val_loss: 0.5945 - val_acc: 0.6276
#
# Epoch 00131: val_loss did not improve from 0.58526
# Epoch 132/150
# 14/14 [==============================] - 6s 408ms/step - loss: 0.5817 - acc: 0.6589 - val_loss: 0.5923 - val_acc: 0.6589
#
# Epoch 00132: val_loss did not improve from 0.58526
# Epoch 133/150
# 14/14 [==============================] - 5s 407ms/step - loss: 0.6066 - acc: 0.6312 - val_loss: 0.6070 - val_acc: 0.6211
#
# Epoch 00133: val_loss did not improve from 0.58526
# Epoch 134/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5975 - acc: 0.6236 - val_loss: 0.6257 - val_acc: 0.6107
#
# Epoch 00134: val_loss did not improve from 0.58526
# Epoch 135/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5801 - acc: 0.6458 - val_loss: 0.6074 - val_acc: 0.6406
#
# Epoch 00135: val_loss did not improve from 0.58526
# Epoch 136/150
# 14/14 [==============================] - 6s 418ms/step - loss: 0.5847 - acc: 0.6503 - val_loss: 0.6242 - val_acc: 0.5964
#
# Epoch 00136: val_loss did not improve from 0.58526
# Epoch 137/150
# 14/14 [==============================] - 6s 423ms/step - loss: 0.5904 - acc: 0.6341 - val_loss: 0.6094 - val_acc: 0.6393
#
# Epoch 00137: val_loss did not improve from 0.58526
# Epoch 138/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5700 - acc: 0.6491 - val_loss: 0.6019 - val_acc: 0.6393
#
# Epoch 00138: val_loss did not improve from 0.58526
# Epoch 139/150
# 14/14 [==============================] - 6s 412ms/step - loss: 0.6018 - acc: 0.6404 - val_loss: 0.6127 - val_acc: 0.6354
#
# Epoch 00139: val_loss did not improve from 0.58526
# Epoch 140/150
# 14/14 [==============================] - 6s 415ms/step - loss: 0.5630 - acc: 0.6509 - val_loss: 0.6211 - val_acc: 0.6094
#
# Epoch 00140: val_loss did not improve from 0.58526
# Epoch 141/150
# 14/14 [==============================] - 6s 410ms/step - loss: 0.5890 - acc: 0.6333 - val_loss: 0.5849 - val_acc: 0.6836
#
# Epoch 00141: val_loss improved from 0.58526 to 0.58495, saving model to checkpoint.h5
# Epoch 142/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5626 - acc: 0.6687 - val_loss: 0.5926 - val_acc: 0.6510
#
# Epoch 00142: val_loss did not improve from 0.58495
# Epoch 143/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.5765 - acc: 0.6609 - val_loss: 0.6192 - val_acc: 0.6289
#
# Epoch 00143: val_loss did not improve from 0.58495
# Epoch 144/150
# 14/14 [==============================] - 5s 402ms/step - loss: 0.5872 - acc: 0.6474 - val_loss: 0.6102 - val_acc: 0.6172
#
# Epoch 00144: val_loss did not improve from 0.58495
# Epoch 145/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5847 - acc: 0.6428 - val_loss: 0.5923 - val_acc: 0.6654
#
# Epoch 00145: val_loss did not improve from 0.58495
# Epoch 146/150
# 14/14 [==============================] - 6s 410ms/step - loss: 0.5868 - acc: 0.6454 - val_loss: 0.5997 - val_acc: 0.6419
#
# Epoch 00146: val_loss did not improve from 0.58495
# Epoch 147/150
# 14/14 [==============================] - 6s 413ms/step - loss: 0.5606 - acc: 0.6730 - val_loss: 0.5949 - val_acc: 0.6419
#
# Epoch 00147: val_loss did not improve from 0.58495
# Epoch 148/150
# 14/14 [==============================] - 5s 405ms/step - loss: 0.5527 - acc: 0.6884 - val_loss: 0.6254 - val_acc: 0.6107
#
# Epoch 00148: val_loss did not improve from 0.58495
# Epoch 149/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5823 - acc: 0.6314 - val_loss: 0.5866 - val_acc: 0.6797
#
# Epoch 00149: val_loss did not improve from 0.58495
# Epoch 150/150
# 14/14 [==============================] - 5s 406ms/step - loss: 0.5844 - acc: 0.6516 - val_loss: 0.5966 - val_acc: 0.6445
#
# Epoch 00150: val_loss did not improve from 0.58495
# Specificity :  0.5251141552511416
# Sensitivity :  0.7008547008547008
#               precision    recall  f1-score   support
#
#            0     0.7667    0.5251    0.6233       219
#            1     0.4409    0.7009    0.5413       117
#
#     accuracy                         0.5863       336
#    macro avg     0.6038    0.6130    0.5823       336
# weighted avg     0.6532    0.5863    0.5947       336
# Result: f2_score=0.627

# %% [markdown]
# ### CNN 3D

# %% [markdown]
# #### Preprocessing
# We perform Data Augmentation with the training set in order to increase the number of data.
#
# We consider geometric transformations, such as the rotation, the vertical and horizontal flip. We choose as fill mode the default value which fills the area with the nearest pixel and stretching it.

# %%
def get_data_gen(data, labels, data_gen_args = {}, seed = 1):
  datagen_abnormality = ImageDataGenerator(**data_gen_args)
  # Provide the same seed and keyword arguments to the fit and flow methods
  datagen_abnormality.fit(data[:,0,:,:,:], seed=seed)


  generator_abnormality = datagen_abnormality.flow(data[:,0,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)
  generator_base = datagen_abnormality.flow(data[:,1,:,:,:], labels, batch_size=BATCH_SIZE, seed=seed)

  # combine generators into one which yields image and masks
  while True:
    abnormality_image, label = generator_abnormality.next()
    base_image, _ = generator_base.next()

    yield np.stack((abnormality_image[:,:,:,0], base_image[:,:,:,0]), axis=-1)[:,:,:,:,np.newaxis], label

# %%
train_datagen_args = dict(
    rotation_range=180,
    vertical_flip = True,
    horizontal_flip = True)

train_generator = get_data_gen(train_images, train_labels, train_datagen_args)

validation_generator = get_data_gen(valid_images, valid_labels)

# %%
for t ,_ in train_generator:
  print(t.shape)
  break
# Out:
# (128, 150, 150, 2, 1)

# %% [markdown]
# #### Experiment 1

# %%
input_shape = (150, 150, 2, 1)
model = models.Sequential()
model.add(layers.Conv3D(32, (3, 3, 1), activation='relu', input_shape=input_shape))
model.add(layers.MaxPooling3D((2, 2, 1)))
model.add(layers.Conv3D(64, (3, 3, 1), activation='relu'))
model.add(layers.MaxPooling3D((2, 2, 1)))
model.add(layers.Conv3D(64, (3, 3, 1), activation='relu'))
model.add(layers.MaxPooling3D((2, 2, 1)))
model.add(layers.Conv3D(128, (3, 3, 1), activation='relu'))
model.add(layers.MaxPooling3D((2, 2, 1)))
model.add(layers.Conv3D(256, (3, 3, 1), activation='relu'))
model.add(layers.MaxPooling3D((2, 2, 1)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy',
              optimizer=keras.optimizers.Adam(),
              metrics=['acc'])

model_checkpoint = ModelCheckpoint('checkpoint.h5', save_best_only=True, save_weights_only=True, verbose=1)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_acc', patience=50)

history = model.fit(
  train_generator,
  steps_per_epoch = len(train_images) // BATCH_SIZE,
  epochs=150,
  class_weight = class_weights,
  validation_data = validation_generator,
  validation_steps =  len(valid_images) // BATCH_SIZE,
  callbacks = [callback, model_checkpoint]
  )
model.load_weights('checkpoint.h5')
performance_plot(history, model, np.stack((test_images[:,0,:,:,0], test_images[:,1,:,:,0]), axis=-1)[:,:,:,:,np.newaxis], test_labels)
models.save_model(model, os.path.join(MODEL_PATH, 'model_3d.h5'))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 148, 148, 2, 32)   320
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 74, 74, 2, 32)     0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 72, 72, 2, 64)     18496
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 36, 36, 2, 64)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 34, 34, 2, 64)     36928
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 17, 17, 2, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 15, 15, 2, 128)    73856
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 7, 7, 2, 128)      0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 5, 5, 2, 256)      295168
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 711,873
# Trainable params: 711,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 14/14 [==============================] - 10s 613ms/step - loss: 0.6987 - acc: 0.5014 - val_loss: 0.6977 - val_acc: 0.4141
#
# Epoch 00001: val_loss improved from inf to 0.69766, saving model to checkpoint.h5
# Epoch 2/150
# 14/14 [==============================] - 7s 545ms/step - loss: 0.6947 - acc: 0.4447 - val_loss: 0.6987 - val_acc: 0.4375
#
# Epoch 00002: val_loss did not improve from 0.69766
# Epoch 3/150
# 14/14 [==============================] - 7s 552ms/step - loss: 0.6838 - acc: 0.5272 - val_loss: 0.6717 - val_acc: 0.5781
#
# Epoch 00003: val_loss improved from 0.69766 to 0.67171, saving model to checkpoint.h5
# Epoch 4/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.6873 - acc: 0.5559 - val_loss: 0.6677 - val_acc: 0.6393
#
# Epoch 00004: val_loss improved from 0.67171 to 0.66770, saving model to checkpoint.h5
# Epoch 5/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6870 - acc: 0.5845 - val_loss: 0.6613 - val_acc: 0.6133
#
# Epoch 00005: val_loss improved from 0.66770 to 0.66133, saving model to checkpoint.h5
# Epoch 6/150
# 14/14 [==============================] - 7s 527ms/step - loss: 0.6826 - acc: 0.5568 - val_loss: 0.6722 - val_acc: 0.6198
#
# Epoch 00006: val_loss did not improve from 0.66133
# Epoch 7/150
# 14/14 [==============================] - 7s 526ms/step - loss: 0.6821 - acc: 0.5848 - val_loss: 0.6851 - val_acc: 0.5078
#
# Epoch 00007: val_loss did not improve from 0.66133
# Epoch 8/150
# 14/14 [==============================] - 7s 528ms/step - loss: 0.6827 - acc: 0.5125 - val_loss: 0.6592 - val_acc: 0.5938
#
# Epoch 00008: val_loss improved from 0.66133 to 0.65925, saving model to checkpoint.h5
# Epoch 9/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6685 - acc: 0.5543 - val_loss: 0.6576 - val_acc: 0.6276
#
# Epoch 00009: val_loss improved from 0.65925 to 0.65760, saving model to checkpoint.h5
# Epoch 10/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6746 - acc: 0.5557 - val_loss: 0.6415 - val_acc: 0.6602
#
# Epoch 00010: val_loss improved from 0.65760 to 0.64154, saving model to checkpoint.h5
# Epoch 11/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.6669 - acc: 0.6006 - val_loss: 0.6630 - val_acc: 0.6315
#
# Epoch 00011: val_loss did not improve from 0.64154
# Epoch 12/150
# 14/14 [==============================] - 7s 535ms/step - loss: 0.6661 - acc: 0.5685 - val_loss: 0.6736 - val_acc: 0.5521
#
# Epoch 00012: val_loss did not improve from 0.64154
# Epoch 13/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6622 - acc: 0.5740 - val_loss: 0.6743 - val_acc: 0.5495
#
# Epoch 00013: val_loss did not improve from 0.64154
# Epoch 14/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6645 - acc: 0.5687 - val_loss: 0.6537 - val_acc: 0.6302
#
# Epoch 00014: val_loss did not improve from 0.64154
# Epoch 15/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6524 - acc: 0.6013 - val_loss: 0.6393 - val_acc: 0.6680
#
# Epoch 00015: val_loss improved from 0.64154 to 0.63928, saving model to checkpoint.h5
# Epoch 16/150
# 14/14 [==============================] - 7s 528ms/step - loss: 0.6638 - acc: 0.5732 - val_loss: 0.6414 - val_acc: 0.6367
#
# Epoch 00016: val_loss did not improve from 0.63928
# Epoch 17/150
# 14/14 [==============================] - 7s 539ms/step - loss: 0.6563 - acc: 0.5992 - val_loss: 0.6484 - val_acc: 0.6276
#
# Epoch 00017: val_loss did not improve from 0.63928
# Epoch 18/150
# 14/14 [==============================] - 7s 549ms/step - loss: 0.6583 - acc: 0.5913 - val_loss: 0.6334 - val_acc: 0.6562
#
# Epoch 00018: val_loss improved from 0.63928 to 0.63341, saving model to checkpoint.h5
# Epoch 19/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6570 - acc: 0.5985 - val_loss: 0.7130 - val_acc: 0.4583
#
# Epoch 00019: val_loss did not improve from 0.63341
# Epoch 20/150
# 14/14 [==============================] - 7s 525ms/step - loss: 0.6652 - acc: 0.5375 - val_loss: 0.6228 - val_acc: 0.6289
#
# Epoch 00020: val_loss improved from 0.63341 to 0.62278, saving model to checkpoint.h5
# Epoch 21/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6424 - acc: 0.5889 - val_loss: 0.6131 - val_acc: 0.6419
#
# Epoch 00021: val_loss improved from 0.62278 to 0.61305, saving model to checkpoint.h5
# Epoch 22/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.6400 - acc: 0.5998 - val_loss: 0.6083 - val_acc: 0.6354
#
# Epoch 00022: val_loss improved from 0.61305 to 0.60833, saving model to checkpoint.h5
# Epoch 23/150
# 14/14 [==============================] - 7s 538ms/step - loss: 0.6432 - acc: 0.5832 - val_loss: 0.5963 - val_acc: 0.6432
#
# Epoch 00023: val_loss improved from 0.60833 to 0.59626, saving model to checkpoint.h5
# Epoch 24/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6326 - acc: 0.6152 - val_loss: 0.5982 - val_acc: 0.6159
#
# Epoch 00024: val_loss did not improve from 0.59626
# Epoch 25/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.6238 - acc: 0.6079 - val_loss: 0.5850 - val_acc: 0.6706
#
# Epoch 00025: val_loss improved from 0.59626 to 0.58505, saving model to checkpoint.h5
# Epoch 26/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6389 - acc: 0.5970 - val_loss: 0.5891 - val_acc: 0.6432
#
# Epoch 00026: val_loss did not improve from 0.58505
# Epoch 27/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6202 - acc: 0.5889 - val_loss: 0.5913 - val_acc: 0.6771
#
# Epoch 00027: val_loss did not improve from 0.58505
# Epoch 28/150
# 14/14 [==============================] - 7s 528ms/step - loss: 0.6235 - acc: 0.6034 - val_loss: 0.5918 - val_acc: 0.6289
#
# Epoch 00028: val_loss did not improve from 0.58505
# Epoch 29/150
# 14/14 [==============================] - 7s 526ms/step - loss: 0.6278 - acc: 0.5933 - val_loss: 0.5881 - val_acc: 0.6693
#
# Epoch 00029: val_loss did not improve from 0.58505
# Epoch 30/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6280 - acc: 0.6337 - val_loss: 0.5813 - val_acc: 0.6602
#
# Epoch 00030: val_loss improved from 0.58505 to 0.58130, saving model to checkpoint.h5
# Epoch 31/150
# 14/14 [==============================] - 7s 526ms/step - loss: 0.6230 - acc: 0.6211 - val_loss: 0.5784 - val_acc: 0.6484
#
# Epoch 00031: val_loss improved from 0.58130 to 0.57841, saving model to checkpoint.h5
# Epoch 32/150
# 14/14 [==============================] - 7s 541ms/step - loss: 0.6092 - acc: 0.6124 - val_loss: 0.5843 - val_acc: 0.6562
#
# Epoch 00032: val_loss did not improve from 0.57841
# Epoch 33/150
# 14/14 [==============================] - 7s 553ms/step - loss: 0.6259 - acc: 0.6245 - val_loss: 0.5788 - val_acc: 0.6641
#
# Epoch 00033: val_loss did not improve from 0.57841
# Epoch 34/150
# 14/14 [==============================] - 7s 540ms/step - loss: 0.6044 - acc: 0.6331 - val_loss: 0.5725 - val_acc: 0.6849
#
# Epoch 00034: val_loss improved from 0.57841 to 0.57251, saving model to checkpoint.h5
# Epoch 35/150
# 14/14 [==============================] - 7s 535ms/step - loss: 0.6130 - acc: 0.6353 - val_loss: 0.5895 - val_acc: 0.6458
#
# Epoch 00035: val_loss did not improve from 0.57251
# Epoch 36/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.6043 - acc: 0.6514 - val_loss: 0.5818 - val_acc: 0.6771
#
# Epoch 00036: val_loss did not improve from 0.57251
# Epoch 37/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6252 - acc: 0.6110 - val_loss: 0.5822 - val_acc: 0.6771
#
# Epoch 00037: val_loss did not improve from 0.57251
# Epoch 38/150
# 14/14 [==============================] - 7s 528ms/step - loss: 0.5983 - acc: 0.6477 - val_loss: 0.6045 - val_acc: 0.6224
#
# Epoch 00038: val_loss did not improve from 0.57251
# Epoch 39/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.6029 - acc: 0.6432 - val_loss: 0.5947 - val_acc: 0.6276
#
# Epoch 00039: val_loss did not improve from 0.57251
# Epoch 40/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.6082 - acc: 0.6378 - val_loss: 0.5761 - val_acc: 0.6706
#
# Epoch 00040: val_loss did not improve from 0.57251
# Epoch 41/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.6012 - acc: 0.6379 - val_loss: 0.5742 - val_acc: 0.6615
#
# Epoch 00041: val_loss did not improve from 0.57251
# Epoch 42/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5930 - acc: 0.6465 - val_loss: 0.5653 - val_acc: 0.6875
#
# Epoch 00042: val_loss improved from 0.57251 to 0.56526, saving model to checkpoint.h5
# Epoch 43/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.5941 - acc: 0.6244 - val_loss: 0.5810 - val_acc: 0.6680
#
# Epoch 00043: val_loss did not improve from 0.56526
# Epoch 44/150
# 14/14 [==============================] - 7s 539ms/step - loss: 0.5881 - acc: 0.6461 - val_loss: 0.5753 - val_acc: 0.6680
#
# Epoch 00044: val_loss did not improve from 0.56526
# Epoch 45/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.6074 - acc: 0.6318 - val_loss: 0.6333 - val_acc: 0.5990
#
# Epoch 00045: val_loss did not improve from 0.56526
# Epoch 46/150
# 14/14 [==============================] - 7s 526ms/step - loss: 0.6142 - acc: 0.6377 - val_loss: 0.5663 - val_acc: 0.6745
#
# Epoch 00046: val_loss did not improve from 0.56526
# Epoch 47/150
# 14/14 [==============================] - 7s 543ms/step - loss: 0.6000 - acc: 0.6309 - val_loss: 0.5748 - val_acc: 0.6706
#
# Epoch 00047: val_loss did not improve from 0.56526
# Epoch 48/150
# 14/14 [==============================] - 7s 548ms/step - loss: 0.5780 - acc: 0.6532 - val_loss: 0.5798 - val_acc: 0.6732
#
# Epoch 00048: val_loss did not improve from 0.56526
# Epoch 49/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5849 - acc: 0.6439 - val_loss: 0.5741 - val_acc: 0.6693
#
# Epoch 00049: val_loss did not improve from 0.56526
# Epoch 50/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5873 - acc: 0.6376 - val_loss: 0.5945 - val_acc: 0.6432
#
# Epoch 00050: val_loss did not improve from 0.56526
# Epoch 51/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5885 - acc: 0.6418 - val_loss: 0.5708 - val_acc: 0.6562
#
# Epoch 00051: val_loss did not improve from 0.56526
# Epoch 52/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5857 - acc: 0.6647 - val_loss: 0.5740 - val_acc: 0.6719
#
# Epoch 00052: val_loss did not improve from 0.56526
# Epoch 53/150
# 14/14 [==============================] - 7s 535ms/step - loss: 0.5878 - acc: 0.6630 - val_loss: 0.5834 - val_acc: 0.6862
#
# Epoch 00053: val_loss did not improve from 0.56526
# Epoch 54/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5984 - acc: 0.6513 - val_loss: 0.5741 - val_acc: 0.6823
#
# Epoch 00054: val_loss did not improve from 0.56526
# Epoch 55/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5837 - acc: 0.6586 - val_loss: 0.6099 - val_acc: 0.6042
#
# Epoch 00055: val_loss did not improve from 0.56526
# Epoch 56/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.6095 - acc: 0.6525 - val_loss: 0.6112 - val_acc: 0.6276
#
# Epoch 00056: val_loss did not improve from 0.56526
# Epoch 57/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5887 - acc: 0.6605 - val_loss: 0.5795 - val_acc: 0.6367
#
# Epoch 00057: val_loss did not improve from 0.56526
# Epoch 58/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.6001 - acc: 0.6520 - val_loss: 0.5761 - val_acc: 0.6641
#
# Epoch 00058: val_loss did not improve from 0.56526
# Epoch 59/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5759 - acc: 0.6607 - val_loss: 0.5790 - val_acc: 0.6849
#
# Epoch 00059: val_loss did not improve from 0.56526
# Epoch 60/150
# 14/14 [==============================] - 7s 528ms/step - loss: 0.5694 - acc: 0.6630 - val_loss: 0.5757 - val_acc: 0.6693
#
# Epoch 00060: val_loss did not improve from 0.56526
# Epoch 61/150
# 14/14 [==============================] - 7s 526ms/step - loss: 0.5925 - acc: 0.6481 - val_loss: 0.6202 - val_acc: 0.6185
#
# Epoch 00061: val_loss did not improve from 0.56526
# Epoch 62/150
# 14/14 [==============================] - 7s 541ms/step - loss: 0.6067 - acc: 0.6326 - val_loss: 0.5819 - val_acc: 0.6432
#
# Epoch 00062: val_loss did not improve from 0.56526
# Epoch 63/150
# 14/14 [==============================] - 7s 551ms/step - loss: 0.5754 - acc: 0.6623 - val_loss: 0.5661 - val_acc: 0.6823
#
# Epoch 00063: val_loss did not improve from 0.56526
# Epoch 64/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.5931 - acc: 0.6591 - val_loss: 0.5811 - val_acc: 0.6380
#
# Epoch 00064: val_loss did not improve from 0.56526
# Epoch 65/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5937 - acc: 0.6497 - val_loss: 0.5768 - val_acc: 0.6641
#
# Epoch 00065: val_loss did not improve from 0.56526
# Epoch 66/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5693 - acc: 0.6982 - val_loss: 0.5689 - val_acc: 0.6823
#
# Epoch 00066: val_loss did not improve from 0.56526
# Epoch 67/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5741 - acc: 0.6682 - val_loss: 0.5934 - val_acc: 0.6536
#
# Epoch 00067: val_loss did not improve from 0.56526
# Epoch 68/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.5572 - acc: 0.6749 - val_loss: 0.5691 - val_acc: 0.6849
#
# Epoch 00068: val_loss did not improve from 0.56526
# Epoch 69/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.5983 - acc: 0.6666 - val_loss: 0.6106 - val_acc: 0.6432
#
# Epoch 00069: val_loss did not improve from 0.56526
# Epoch 70/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5639 - acc: 0.6510 - val_loss: 0.5766 - val_acc: 0.6667
#
# Epoch 00070: val_loss did not improve from 0.56526
# Epoch 71/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5934 - acc: 0.6485 - val_loss: 0.5652 - val_acc: 0.6758
#
# Epoch 00071: val_loss improved from 0.56526 to 0.56519, saving model to checkpoint.h5
# Epoch 72/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5937 - acc: 0.6658 - val_loss: 0.5974 - val_acc: 0.6458
#
# Epoch 00072: val_loss did not improve from 0.56519
# Epoch 73/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.5695 - acc: 0.6533 - val_loss: 0.5816 - val_acc: 0.6562
#
# Epoch 00073: val_loss did not improve from 0.56519
# Epoch 74/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5544 - acc: 0.6802 - val_loss: 0.6090 - val_acc: 0.6471
#
# Epoch 00074: val_loss did not improve from 0.56519
# Epoch 75/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.6029 - acc: 0.6392 - val_loss: 0.5783 - val_acc: 0.6823
#
# Epoch 00075: val_loss did not improve from 0.56519
# Epoch 76/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.5874 - acc: 0.6685 - val_loss: 0.5773 - val_acc: 0.6576
#
# Epoch 00076: val_loss did not improve from 0.56519
# Epoch 77/150
# 14/14 [==============================] - 7s 549ms/step - loss: 0.5858 - acc: 0.6771 - val_loss: 0.5838 - val_acc: 0.6940
#
# Epoch 00077: val_loss did not improve from 0.56519
# Epoch 78/150
# 14/14 [==============================] - 7s 555ms/step - loss: 0.5917 - acc: 0.6460 - val_loss: 0.5712 - val_acc: 0.6615
#
# Epoch 00078: val_loss did not improve from 0.56519
# Epoch 79/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5745 - acc: 0.6850 - val_loss: 0.5973 - val_acc: 0.6680
#
# Epoch 00079: val_loss did not improve from 0.56519
# Epoch 80/150
# 14/14 [==============================] - 7s 530ms/step - loss: 0.5369 - acc: 0.6990 - val_loss: 0.5919 - val_acc: 0.6602
#
# Epoch 00080: val_loss did not improve from 0.56519
# Epoch 81/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5466 - acc: 0.6813 - val_loss: 0.5964 - val_acc: 0.6445
#
# Epoch 00081: val_loss did not improve from 0.56519
# Epoch 82/150
# 14/14 [==============================] - 7s 547ms/step - loss: 0.5731 - acc: 0.6638 - val_loss: 0.5908 - val_acc: 0.6758
#
# Epoch 00082: val_loss did not improve from 0.56519
# Epoch 83/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.5395 - acc: 0.6910 - val_loss: 0.5883 - val_acc: 0.6771
#
# Epoch 00083: val_loss did not improve from 0.56519
# Epoch 84/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.5538 - acc: 0.6761 - val_loss: 0.6067 - val_acc: 0.6523
#
# Epoch 00084: val_loss did not improve from 0.56519
# Epoch 85/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.5728 - acc: 0.6710 - val_loss: 0.5909 - val_acc: 0.6549
#
# Epoch 00085: val_loss did not improve from 0.56519
# Epoch 86/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.5708 - acc: 0.6800 - val_loss: 0.5867 - val_acc: 0.6836
#
# Epoch 00086: val_loss did not improve from 0.56519
# Epoch 87/150
# 14/14 [==============================] - 7s 539ms/step - loss: 0.5725 - acc: 0.6969 - val_loss: 0.5905 - val_acc: 0.6771
#
# Epoch 00087: val_loss did not improve from 0.56519
# Epoch 88/150
# 14/14 [==============================] - 7s 539ms/step - loss: 0.5826 - acc: 0.6672 - val_loss: 0.5943 - val_acc: 0.6419
#
# Epoch 00088: val_loss did not improve from 0.56519
# Epoch 89/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5596 - acc: 0.6922 - val_loss: 0.5955 - val_acc: 0.6602
#
# Epoch 00089: val_loss did not improve from 0.56519
# Epoch 90/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5603 - acc: 0.6945 - val_loss: 0.5817 - val_acc: 0.6745
#
# Epoch 00090: val_loss did not improve from 0.56519
# Epoch 91/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5384 - acc: 0.7018 - val_loss: 0.5751 - val_acc: 0.6862
#
# Epoch 00091: val_loss did not improve from 0.56519
# Epoch 92/150
# 14/14 [==============================] - 7s 544ms/step - loss: 0.5365 - acc: 0.7029 - val_loss: 0.5823 - val_acc: 0.6810
#
# Epoch 00092: val_loss did not improve from 0.56519
# Epoch 93/150
# 14/14 [==============================] - 7s 554ms/step - loss: 0.5518 - acc: 0.6854 - val_loss: 0.5782 - val_acc: 0.6706
#
# Epoch 00093: val_loss did not improve from 0.56519
# Epoch 94/150
# 14/14 [==============================] - 7s 543ms/step - loss: 0.5371 - acc: 0.6896 - val_loss: 0.6259 - val_acc: 0.6484
#
# Epoch 00094: val_loss did not improve from 0.56519
# Epoch 95/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5952 - acc: 0.6488 - val_loss: 0.5899 - val_acc: 0.6706
#
# Epoch 00095: val_loss did not improve from 0.56519
# Epoch 96/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5664 - acc: 0.6889 - val_loss: 0.5720 - val_acc: 0.6732
#
# Epoch 00096: val_loss did not improve from 0.56519
# Epoch 97/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5542 - acc: 0.6828 - val_loss: 0.5877 - val_acc: 0.6680
#
# Epoch 00097: val_loss did not improve from 0.56519
# Epoch 98/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5411 - acc: 0.6942 - val_loss: 0.6074 - val_acc: 0.6732
#
# Epoch 00098: val_loss did not improve from 0.56519
# Epoch 99/150
# 14/14 [==============================] - 7s 538ms/step - loss: 0.5293 - acc: 0.7214 - val_loss: 0.5903 - val_acc: 0.6771
#
# Epoch 00099: val_loss did not improve from 0.56519
# Epoch 100/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5580 - acc: 0.6849 - val_loss: 0.5884 - val_acc: 0.6849
#
# Epoch 00100: val_loss did not improve from 0.56519
# Epoch 101/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5254 - acc: 0.7006 - val_loss: 0.6152 - val_acc: 0.6719
#
# Epoch 00101: val_loss did not improve from 0.56519
# Epoch 102/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5549 - acc: 0.6871 - val_loss: 0.6613 - val_acc: 0.6211
#
# Epoch 00102: val_loss did not improve from 0.56519
# Epoch 103/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5636 - acc: 0.6661 - val_loss: 0.5938 - val_acc: 0.6745
#
# Epoch 00103: val_loss did not improve from 0.56519
# Epoch 104/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5501 - acc: 0.6883 - val_loss: 0.5935 - val_acc: 0.6706
#
# Epoch 00104: val_loss did not improve from 0.56519
# Epoch 105/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5296 - acc: 0.6947 - val_loss: 0.6002 - val_acc: 0.6784
#
# Epoch 00105: val_loss did not improve from 0.56519
# Epoch 106/150
# 14/14 [==============================] - 7s 529ms/step - loss: 0.5247 - acc: 0.7028 - val_loss: 0.5963 - val_acc: 0.6706
#
# Epoch 00106: val_loss did not improve from 0.56519
# Epoch 107/150
# 14/14 [==============================] - 7s 549ms/step - loss: 0.5197 - acc: 0.7193 - val_loss: 0.6087 - val_acc: 0.6810
#
# Epoch 00107: val_loss did not improve from 0.56519
# Epoch 108/150
# 14/14 [==============================] - 7s 551ms/step - loss: 0.5250 - acc: 0.7119 - val_loss: 0.6338 - val_acc: 0.6523
#
# Epoch 00108: val_loss did not improve from 0.56519
# Epoch 109/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5265 - acc: 0.7146 - val_loss: 0.6330 - val_acc: 0.6732
#
# Epoch 00109: val_loss did not improve from 0.56519
# Epoch 110/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5314 - acc: 0.6994 - val_loss: 0.6312 - val_acc: 0.6510
#
# Epoch 00110: val_loss did not improve from 0.56519
# Epoch 111/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5172 - acc: 0.7108 - val_loss: 0.6467 - val_acc: 0.6549
#
# Epoch 00111: val_loss did not improve from 0.56519
# Epoch 112/150
# 14/14 [==============================] - 7s 532ms/step - loss: 0.5026 - acc: 0.7215 - val_loss: 0.6314 - val_acc: 0.6758
#
# Epoch 00112: val_loss did not improve from 0.56519
# Epoch 113/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5373 - acc: 0.7080 - val_loss: 0.6540 - val_acc: 0.6562
#
# Epoch 00113: val_loss did not improve from 0.56519
# Epoch 114/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5271 - acc: 0.7028 - val_loss: 0.6122 - val_acc: 0.6680
#
# Epoch 00114: val_loss did not improve from 0.56519
# Epoch 115/150
# 14/14 [==============================] - 7s 534ms/step - loss: 0.5267 - acc: 0.7031 - val_loss: 0.6554 - val_acc: 0.6497
#
# Epoch 00115: val_loss did not improve from 0.56519
# Epoch 116/150
# 14/14 [==============================] - 7s 531ms/step - loss: 0.5323 - acc: 0.6932 - val_loss: 0.6042 - val_acc: 0.6654
#
# Epoch 00116: val_loss did not improve from 0.56519
# Epoch 117/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5289 - acc: 0.7136 - val_loss: 0.6539 - val_acc: 0.6367
#
# Epoch 00117: val_loss did not improve from 0.56519
# Epoch 118/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5206 - acc: 0.6978 - val_loss: 0.6415 - val_acc: 0.6667
#
# Epoch 00118: val_loss did not improve from 0.56519
# Epoch 119/150
# 14/14 [==============================] - 7s 538ms/step - loss: 0.5167 - acc: 0.7149 - val_loss: 0.6739 - val_acc: 0.6589
#
# Epoch 00119: val_loss did not improve from 0.56519
# Epoch 120/150
# 14/14 [==============================] - 7s 542ms/step - loss: 0.4994 - acc: 0.7212 - val_loss: 0.6447 - val_acc: 0.6706
#
# Epoch 00120: val_loss did not improve from 0.56519
# Epoch 121/150
# 14/14 [==============================] - 7s 533ms/step - loss: 0.5013 - acc: 0.7260 - val_loss: 0.6669 - val_acc: 0.6602
#
# Epoch 00121: val_loss did not improve from 0.56519
# Epoch 122/150
# 14/14 [==============================] - 7s 550ms/step - loss: 0.5030 - acc: 0.7225 - val_loss: 0.6450 - val_acc: 0.6602
#
# Epoch 00122: val_loss did not improve from 0.56519
# Epoch 123/150
# 14/14 [==============================] - 7s 561ms/step - loss: 0.5010 - acc: 0.6987 - val_loss: 0.6820 - val_acc: 0.6484
#
# Epoch 00123: val_loss did not improve from 0.56519
# Epoch 124/150
# 14/14 [==============================] - 7s 537ms/step - loss: 0.5275 - acc: 0.7076 - val_loss: 0.6597 - val_acc: 0.6823
#
# Epoch 00124: val_loss did not improve from 0.56519
# Epoch 125/150
# 14/14 [==============================] - 7s 535ms/step - loss: 0.5054 - acc: 0.7203 - val_loss: 0.6561 - val_acc: 0.6497
#
# Epoch 00125: val_loss did not improve from 0.56519
# Epoch 126/150
# 14/14 [==============================] - 7s 535ms/step - loss: 0.5191 - acc: 0.6990 - val_loss: 0.6496 - val_acc: 0.6641
#
# Epoch 00126: val_loss did not improve from 0.56519
# Epoch 127/150
# 14/14 [==============================] - 7s 536ms/step - loss: 0.5145 - acc: 0.7154 - val_loss: 0.6832 - val_acc: 0.6250
#
# Epoch 00127: val_loss did not improve from 0.56519
# Specificity :  0.6621004566210046
# Sensitivity :  0.6923076923076923
#               precision    recall  f1-score   support
#
#            0     0.8011    0.6621    0.7250       219
#            1     0.5226    0.6923    0.5956       117
#
#     accuracy                         0.6726       336
#    macro avg     0.6618    0.6772    0.6603       336
# weighted avg     0.7041    0.6726    0.6799       336
# Result: f2_score=0.650

# %% [markdown]
# ## Error Analysis

# %%
import seaborn as sns

def get_errors(pred, test_label, test_data):
    errors = []
    mispred = []
    for l, p, images in zip(test_label, pred, test_data):
        err = abs(l-p)
        errors.append(err)
        c = 1 if p>0.5 else 0
        if l == 1 and c== 0 and err > 0.5:
            mispred.append((l,p,images))

    return errors, mispred

def show_error_stats(errors, mispred, test_data):

    print("Number of test images: %d" % test_data.shape[0])
    print("Mispredictions: %d" % len(mispred))
    for l, p, img in mispred:
        plt.figure()
        plt.imshow(np.hstack((img[:,:,0, 0], np.ones((150, 150)) , img[:,:,1, 0])), cmap='gray')
        plt.title('Misclassified as ' + ('benign' if l==1 else 'malignant') + ' with %.2f confidence' % (100*abs(p-l)) + ' Abnormality at left')

opt_model = models.load_model(os.path.join(MODEL_PATH, 'model_3d.h5'))
pred_opt = opt_model.predict(np.stack((test_images[:,0,:,:,0], test_images[:,1,:,:,0]), axis=-1)[:,:,:,:,np.newaxis])

errors, mispred = get_errors(pred_opt, test_labels, np.stack((test_images[:,0,:,:,0], test_images[:,1,:,:,0]), axis=-1)[:,:,:,:,np.newaxis])

show_error_stats(errors, mispred, np.stack((test_images[:,0,:,:,0], test_images[:,1,:,:,0]), axis=-1)[:,:,:,:,np.newaxis])
# Out:
# Number of test images: 336
# Mispredictions: 36
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
